# %% [markdown]
# ## SQL - part 3

# %%
from sqlite3 import connect

'''    
    Establish a connection to the database.
    This statement creates the file iat the given path if it does not exist.
    The file was provided so the statement should just establish the connection.
'''
connection = connect('../datasets/org.Hs.eg.sqlite')
cursor = connection.cursor()

# %% [markdown]
# #### Major SQL commands: SELECT, INSERT, DELETE, UPDATE
# #### SELECT - Retrieves data from one or more tables and doesn’t change the data at all
#
# * SELECT  * (means all columns), or the comma separated names of the columns of data you wish to return
#     * Returns columns (left to right) in the order received.
#     * '*' selects ALL rows and ALL columns and returns them by column order and row_id
# * FROM is the table source or sources (comma separated)
# * WHERE (optional) is the predicate clause: conditions for the query
#     * Evaluates to True or False for each row
#     * This clause almost always includes Column-Value pairs.
#     * Omitting the Where clause returns ALL the records in that table.
#     * Note: the match is case sensitive
# * ORDER BY (optional) indicates a sort order for the output data
#     * default is row_id, which can be very non-intuitive
#     * ASCending or DESCending can be appended to change the sort order.  (ASC is default)
# * GROUP BY (optional) groups by a column and creates summary data for a different column
# * HAVING (optional) allows restrictions on the rows selected
#     * a GROUP BY clause is required before HAVING
# * LIMIT (optional) reduces the number of rows retrieved to the number provided after this clause
# * In most SQL clients, the ";" indicates the end of a statement and requests execution

# %%
def get_header(cursor):
    '''
    Makes a tab delimited header row from the cursor description.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    '''
    return '\t'.join([row[0] for row in cursor.description])

def get_results(cursor):
    '''
    Makes a tab delimited table from the cursor results.
    Arguments:
        cursor: a cursor after a select query
    Returns:
        string: A string consisting of the column names separated by tabs, no new line
    ''' 
    res = list()
    for row in cursor.fetchall():        
        res.append('\t'.join(list(map(str,row))))
    return "\n".join(res)

# %%
# In every SQLite database, there is a special table: sqlite_master
# sqlite_master -  describes the contents of the database

sql = '''
SELECT type, name 
FROM sqlite_master 
WHERE type = "table";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# type	name
# table	metadata
# table	map_metadata
# table	map_counts
# table	genes
# table	gene_info
# table	chromosomes
# table	accessions
# table	cytogenetic_locations
# table	omim
# table	refseq
# table	pubmed
# table	unigene
# table	chrlengths
# table	go_bp
# table	go_mf
# table	go_cc
# table	go_bp_all
# table	go_mf_all
# table	go_cc_all
# table	kegg
# table	ec
# table	chromosome_locations
# table	pfam
# table	prosite
# table	alias
# table	ensembl
# table	ensembl2ncbi
# table	ncbi2ensembl
# table	ensembl_prot
# table	ensembl_trans
# table	uniprot
# table	ucsc
# table	sqlite_stat1
# table	sqlite_stat4
# table	sqlite_sequence

# %% [markdown]
# #### A `PRIMARY KEY` is a very important concept to understand.
# * It is the designation for a column or a set of columns from a table.
# * It is recommended to be a serial value and not something related to the business needs of the data in the table.
#
# * A primary key is used to uniquely identify a row of data; combined with a column name, uniquely locates a data entry
# * A primary key by definition must be `UNIQUE` and `NOT NULL`
# * The primary key of a table, should be a (sequential) non-repeating and not null value
# * Primary keys are generally identified at time of table creation
# * A common method for generating a primary key, is to set the datatype to `INTEGER` and declare `AUTOINCREMENT` which will function when data is inserted into the table
# * Primary keys can be a composite of 2 or more columns that uniquely identify the data in the table

# %% [markdown]
# #### A `FOREIGN KEY` is a column(s) that points to the `PRIMARY KEY` of another table
#
# * The purpose of the foreign key is to ensure referential integrity of the data.
# In other words, only values that are supposed to appear in the database are permitted.<br>
# Only the values that exist in the `PRIMARY KEY` column are allowed to be present in the FOREIGN KEY column.
#
# They are also the underpinning of how tables are joined and relationships portrayed in the database

# %% [markdown]
# #### JOIN tables
#
# * Multiple tables contain different data that we want to retrieve from a single query
# * In order to assemble data as part of a query, a JOIN between tables is needed
# * This is a very common practice, since it’s rare for all the data you want to be in a single table
#
#
# * INNER JOIN - return only those rows where there is matching content in BOTH tables (is the default when JOIN is used)
# * OUTER JOIN - returns all rows from both tables even if one of the tables is blank
# * SELF JOIN - can be used to join a table to itself (through aliasing), to compare data internal to the table
#
# ```sql
# SELECT ... FROM table1 [INNER] JOIN table2 ON conditional_expression
# ```

# %%
sql = '''
SELECT *
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id = go._id
--WHERE evidence = "ND"
LIMIT 5;'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# _id	gene_name	symbol	_id	go_id	evidence
# 1	alpha-1-B glycoprotein	A1BG	1	GO:0002576	TAS
# 1	alpha-1-B glycoprotein	A1BG	1	GO:0008150	ND
# 1	alpha-1-B glycoprotein	A1BG	1	GO:0043312	TAS
# 2	alpha-2-macroglobulin	A2M	2	GO:0001869	IDA
# 2	alpha-2-macroglobulin	A2M	2	GO:0002576	TAS

# %%
# gene information for gene with the max number of associated go terms
sql = '''
SELECT gi.symbol, go_term_no
FROM gene_info AS gi
INNER JOIN 
(SELECT _id, count(go_id) AS go_term_no
FROM go_bp
GROUP BY _id) AS go
ON gi._id == go._id
WHERE go_term_no IN 
(SELECT max(go_term_no) FROM
(SELECT _id, count(go_id) AS go_term_no
FROM go_bp
GROUP BY _id));
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# symbol	go_term_no
# TGFB1	199

# %%
# gene information for gene with the max number of associated go terms
sql = '''
SELECT _id, count(go_id) AS go_term_no1
FROM go_bp
GROUP BY _id
HAVING go_term_no1 IN
(
SELECT max(go_term_no)
FROM
(SELECT _id, count(go_id) AS go_term_no
FROM go_bp
GROUP BY _id
)
);
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# _id	go_term_no1
# 5710	199

# %%
# gene information for gene with the max number of associated go terms
sql = '''
SELECT * 
FROM gene_info
WHERE _id IN
(
SELECT _id FROM
(
SELECT _id, count(go_id) AS go_term_no1
FROM go_bp
GROUP BY _id
HAVING go_term_no1 IN
(
SELECT max(go_term_no)
FROM
(SELECT _id, count(go_id) AS go_term_no
FROM go_bp
GROUP BY _id
)
)));
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# _id	gene_name	symbol
# 5710	transforming growth factor beta 1	TGFB1

# %% [markdown]
# #### See the create table statement

# %%
# sql column in the sqlite_master table

sql = '''
SELECT sql
FROM sqlite_master 
WHERE type= "table" and name == "go_bp";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# sql
# CREATE TABLE go_bp (
#       _id INTEGER NOT NULL,                         -- REFERENCES  genes
#       go_id CHAR(10) NOT NULL,                      -- GO ID
#       evidence CHAR(3) NOT NULL,                    -- GO evidence code
#       FOREIGN KEY (_id) REFERENCES  genes  (_id)
#     )

# %% [markdown]
# #### Guidelines for database design:
#
# * Normalization is the process of creating or re-arranging data relationships so that it will be easy to store and retrieve data efficiently.  Data is normalized to achieve the following goals:
#     * Eliminate data redundancies and save space
#     * Make it easier to change data
#     * Simplify the enforcement of referential integrity constraints
#     * Produce a design that is a 'good' representation of the real world (one that is intuitively easy to understand and a good base for further growth)
#
#     * Make it easier to change data by avoiding to provide multiple values separated by commas in a column
#     * All columns in a table should depend on the primary key, all extra related information should be in other tables linked by foreign keys
#
# https://support.microsoft.com/en-us/help/283878/description-of-the-database-normalization-basics

# %% [markdown]
# ### CREATE TABLE  - statement
# https://www.sqlitetutorial.net/sqlite-create-table/
#
# ```sql
# CREATE TABLE [IF NOT EXISTS] [schema_name].table_name (
#     column_1 data_type PRIMARY KEY,
#     column_2 data_type NOT NULL,
#     column_3 data_type DEFAULT 0,
#     table_constraints
# ) [WITHOUT ROWID];
# ```
#
# In this syntax:
#
# * First, specify the name of the table that you want to create after the CREATE TABLE keywords. The name of the table cannot start with sqlite_ because it is reserved for the internal use of SQLite.
# * Second, use `IF NOT EXISTS` option to create a new table if it does not exist. Attempting to create a table that already exists without using the IF NOT EXISTS option will result in an error.
# * Third, optionally specify the schema_name to which the new table belongs. The schema can be the main database, temp database or any attached database.
# * Fourth, specify the column list of the table. Each column has a name, data type, and the column constraint. SQLite supports `PRIMARY KEY, UNIQUE, NOT NULL`, and `CHECK` column constraints.
# * Fifth, specify the table constraints such as PRIMARY KEY, FOREIGN KEY, UNIQUE, and CHECK constraints.
# * Finally, optionally use the `WITHOUT ROWID` option. By default, a row in a table has an implicit column, which is referred to as the rowid, oid or _rowid_ column. The rowid column stores a 64-bit signed integer key that uniquely identifies the row inside the table. If you don’t want SQLite creates the rowid column, you specify the WITHOUT ROWID option. A table that contains the rowid column is known as a rowid table. Note that the WITHOUT ROWID option is only available in SQLite 3.8.2 or later.

# %% [markdown]
# https://www.sqlite.org/syntaxdiagrams.html#create-table-stmt
#
# <img src = "https://www.sqlite.org/images/syntax/create-table-stmt.gif" width="800"/>

# %% [markdown]
# Each value stored in an SQLite database (or manipulated by the database engine) has one of the following storage classes:
# https://www.sqlite.org/datatype3.html
# * `NULL`. The value is a NULL value.
# * `INTEGER`. The value is a signed integer, stored in 1, 2, 3, 4, 6, or 8 bytes depending on the magnitude of the value.
# * `REAL`. The value is a floating point value, stored as an 8-byte IEEE floating point number.
# * `TEXT`. The value is a text string, stored using the database encoding (UTF-8, UTF-16BE or UTF-16LE).
# * `BLOB`. The value is a blob of data, stored exactly as it was input.

# %% [markdown]
# The `sqlite_master` has the following create statement:
# ```sql
# CREATE TABLE sqlite_master ( type TEXT, name TEXT, tbl_name TEXT, rootpage INTEGER, sql TEXT );
# ```

# %% [markdown]
# #### Create the table `gene` with the columns: `gene_id`, `gene_symbol`. `gene_name`

# %% [markdown]
# ##### The `connection` object methods can be used to save or revert/reset the changes after a command that makes changes to the database
# ##### `COMMIT` - save the changes
# ##### `ROLLBACK` - revert the changes

# %%
sql='''
CREATE TABLE IF NOT EXISTS go_bp_ALT (
      gene_go_id INTEGER PRIMARY KEY AUTOINCREMENT,
      gene_id INTEGER NOT NULL,                     -- REFERENCES  genes _id 
      go_id CHAR(10) NOT NULL,                      -- GO ID
      evidence CHAR(30) NOT NULL,                   -- GO evidence information
      FOREIGN KEY (gene_id) REFERENCES  genes  (_id)
    );
'''
try:
    cursor.execute(sql)
except connection.DatabaseError:
    print("Creating the go_bp_ALT table resulted in a database error!")
    connection.rollback()
    raise
else:
    connection.commit()
finally:
    print("done!")
# Out:
# done!

# %% [markdown]
# ##### Similar error handling, as seen above, can be when executing any statement that changes the database.

# %% [markdown]
# ##### Check if the new table appears in the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master 
WHERE name LIKE "go_bp%"
LIMIT 4;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('go_bp',), ('go_bp_all',), ('go_bp_ALT',)]

# %% [markdown]
#
# <br><br>
# The `sqlite_sequence` table is created and initialized automatically whenever a regular table is created if it has a column with the `AUTOINCREMENT` option set.<br>
# https://www.sqlite.org/autoinc.html

# %% [markdown]
# ##### Check if the new table appears in the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master 
WHERE name LIKE "sqlite_%"
LIMIT 10;
'''
cursor.execute(sql)
print(cursor.fetchall())
# Out:
# [('sqlite_autoindex_metadata_1',), ('sqlite_autoindex_map_counts_1',), ('sqlite_autoindex_genes_1',), ('sqlite_autoindex_gene_info_1',), ('sqlite_autoindex_chrlengths_1',), ('sqlite_stat1',), ('sqlite_stat4',), ('sqlite_sequence',)]

# %% [markdown]
# ### INDEXING
#
# Indexes are lookup table, like the index of a book.
# They are usually created for columns that have unique/ or less redundant values and provide a way to quicky search
# the values.<br>
# Indexing creates a copy of the indexed columns together with a link to the location of the additional information.<br>
# The index data is stored in a data structure that allows for fast sorting. <br>
# E.g.: balanced-tree - every leaf is at most n nodes away from the root) that allows for fast sorting. <br>
# All queries (statements) regarding an indexed table are applied to the index
#
#
# * One important function in Relational Databases is to be able to create indexes on columns in tables
# * These indexes are pre-calculated and stored in the database
# * Indexes should be created on columns that are used in queries and joins
#     * columns that appear in conditions (WHERE, JOIN ... ON)
# * They will rapidly speed up query return rate and improve query performance
#
# To create an index use the following command:
#
# ```sql
# CREATE INDEX indexName ON tableName (columnName)
# ```

# %%
sql = '''
CREATE INDEX gene_go_idx 
ON go_bp_ALT (gene_go_id)
'''
cursor.execute(sql)
connection.commit()

# %% [markdown]
# ##### Check if the new index appears in the `sqlite_master` table

# %%
sql = '''
SELECT name
FROM sqlite_master 
WHERE type= "index";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name
# sqlite_autoindex_metadata_1
# sqlite_autoindex_map_counts_1
# sqlite_autoindex_genes_1
# sqlite_autoindex_gene_info_1
# sqlite_autoindex_chrlengths_1
# Fchromosomes
# Faccessions
# Fcytogenetic_locations
# Fomim
# Frefseq
# Fpubmed
# Funigene
# Fgo_bp
# Fgo_bp_go_id
# Fgo_mf
# Fgo_mf_go_id
# Fgo_cc
# Fgo_cc_go_id
# Fgo_bp_all
# Fgo_bp_all_go_id
# Fgo_mf_all
# Fgo_mf_all_go_id
# Fgo_cc_all
# Fgo_cc_all_go_id
# Fkegg
# Fec
# Fchromosome_locations
# Fpfam
# Fprosite
# Falias
# Fensembl
# Fensembl2ncbi
# Fncbi2ensembl
# Fensemblp
# Fensemblt
# Funiprot
# Fucsc
# gene_go_idx

# %% [markdown]
# #### Remove the index

# %%
sql = '''
DROP INDEX gene_go_idx 
'''
cursor.execute(sql)
connection.commit()

# %% [markdown]
# ##### Check if the index was removed from the `sqlite_master` table

# %%
sql = '''
SELECT name, sql
FROM sqlite_master 
WHERE type= "index" AND name = "gene_go_idx";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# name	sql

# %% [markdown]
# ### INSERT - statement
#
# Makes changes to the database table<br>
# Adds new data to a table (if the constraints are met)
# Constraint examples:
# * For one designated column or a group of columns that are designated as Primary Key the values are unique
# * The value inserted in a column that has a Foreign Key constraint should exist in the column that it refers to
#
# ```sql
# INSERT INTO <tablename> (<column1>, <column2>, <column3>) VALUES (value1, value2, value3);
# ```
#
# ##### One simple INSERT command adds 1 row of data at a time into an existing table
#
# ##### Connection object allows us to:
# * ##### COMMIT - save the changes
# * ##### ROLLBACK - reverts/discards the changes

# %% [markdown]
# <br>
#
# ##### Let's see what is in the table (it should be nothing):

# %%
sql = '''
SELECT *
FROM go_bp_ALT;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence

# %% [markdown]
# <br>
#
# ##### Let's try an insert:
# ```sql
# INSERT INTO <tablename> (<column1>, <column2>, <column3>) VALUES (value1, value2, value3);
# ```

# %%
values_list = [1234,"GO:1234","CM_EV"]

sql = '''
INSERT INTO go_bp_ALT (gene_id, go_id, evidence) 
VALUES (?,?,?);
'''
cursor.execute(sql,values_list)
connection.commit()

# %%
# This command retrieves the identifier of the last row from the most current query
# The gene_go_id

id_value = cursor.lastrowid
id_value
# Out:
# 1

# %% [markdown]
# <br>
#
#
# ##### We have a row in the table!!! And the gene_go_id was automatically generated.

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence
# 1	1234	GO:1234	CM_EV

# %% [markdown]
# #### You can have a Python "table" structure (list of lists) of insert values and get them all inserted in one command, each sublist having the correct number of values.

# %%
values_tbl = [[1235,"GO:1235","CM_EV"], [1236,"GO:1236","CM_EV"], [1236,"GO:1237","CM_EV"]]

sql = '''
INSERT INTO go_bp_ALT (gene_id, go_id, evidence) 
VALUES (?,?,?);
'''
cursor.executemany(sql,values_tbl)
connection.commit()

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence
# 1	1234	GO:1234	CM_EV
# 2	1235	GO:1235	CM_EV
# 3	1236	GO:1236	CM_EV
# 4	1236	GO:1237	CM_EV

# %%
go_tbl = [["GO:1238","ND"], ["GO:1239","ND"], ["GO:1240","IDE"]]
gene_id = 4
for go_elem in go_tbl:
    go_elem.insert(0,gene_id) 
print(go_tbl)
sql = '''
INSERT INTO go_bp_ALT (gene_id, go_id, evidence) 
VALUES (?,?,?);
'''
cursor.executemany(sql,go_tbl)
connection.commit()
# Out:
# [[4, 'GO:1238', 'ND'], [4, 'GO:1239', 'ND'], [4, 'GO:1240', 'IDE']]

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence
# 1	1234	GO:1234	CM_EV
# 2	1235	GO:1235	CM_EV
# 3	1236	GO:1236	CM_EV
# 4	1236	GO:1237	CM_EV
# 5	4	GO:1238	ND
# 6	4	GO:1239	ND
# 7	4	GO:1240	IDE

# %% [markdown]
# #### UPDATE - statement - changes the table rows

# %% [markdown]
# Modifies data (already in a table)  in all rows matching the WHERE clause
#
# ```sql
# UPDATE table_name
# SET column1 = value1, column2 = value2...., columnN = valueN
# WHERE [condition];
# ```
#
# Update is generally a single row command, but use of the where clause can cause data to be updated in multiple rows <br>
# (whether you intended to or not !!!!)
#
# The following statement updates the evidence for all entries for all genes associated with the 2 biological processses

# %%
sql = '''
UPDATE go_bp_ALT
SET gene_id = 5, go_id = "GO:1234" 
WHERE gene_id = 4;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence
# 2	1235	GO:1235	CM_EV
# 4	1236	GO:1237	CM_EV

# %% [markdown]
# #### DELETE - statement - deletes table rows
#
# * MAKES CHANGES TO THE DATA
# * Row level deletion – can’t delete less than this.
#
# ```sql
# DELETE FROM <tablename> WHERE <column> = <value>
# ```
#
# * The WHERE predicate is the same as for the SELECT statement, that is, it determines which rows will be deleted

# %%
sql = '''
DELETE FROM go_bp_ALT 
WHERE go_id IN ("GO:1234","GO:1236");
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence
# 2	1235	GO:1235	CM_EV
# 4	1236	GO:1237	CM_EV

# %% [markdown]
# ```sql
# DELETE FROM <tablename>;
# ```
#
# * This would delete all rows of data from a table.
# * Preserves table structure (table still exists)
# * Optimized for speed in SQLite, no row-by-row execution.
# * EXISTS <table_name> still evaluates to True

# %%
sql = '''
DELETE FROM go_bp_ALT;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT *
FROM go_bp_ALT ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# gene_go_id	gene_id	go_id	evidence

# %% [markdown]
# <br>
#
# #### `DROP TABLE` - statement - removes a table (permanently)

# %%
sql = '''
DROP TABLE IF EXISTS go_bp_ALT;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT name AS "TABLE NAME"
FROM sqlite_master 
WHERE name LIKE "go_bp%";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# TABLE NAME
# go_bp
# go_bp_all

# %% [markdown]
# #### VIEW in a database
#
# * A view is a virtual table which can be created from a query on existing tables
# * Views are created to give a more human readable version of the normalized data / tables
# * http://www.sqlitetutorial.net/sqlite-create-view/
# * An SQLite view is read only

# %% [markdown]
# ```sql
# CREATE [TEMP] VIEW [IF NOT EXISTS] view_name(column-name-list) AS
# select-statement;
# ```

# %%
# gene go information for easy access
sql = '''
SELECT symbol, go_id, evidence
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id == go._id
WHERE evidence IN ("EXP","IDA") ;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# symbol	go_id	evidence
# A2M	GO:0001869	IDA
# AANAT	GO:0006474	IDA
# AANAT	GO:0030187	IDA
# AANAT	GO:0071320	IDA
# AARS	GO:0006419	IDA
# ABCA1	GO:0007040	IDA
# ABCA1	GO:0008203	IDA
# ABCA1	GO:0016197	IDA
# ABCA1	GO:0033344	IDA
# ABCA1	GO:0033700	IDA
# ABCA1	GO:0042632	IDA
# ABCA1	GO:0045332	IDA
# ABCA2	GO:0006357	IDA
# ABCA4	GO:0045332	IDA
# ABL1	GO:0006974	IDA
# ABL1	GO:0006975	IDA
# ABL1	GO:0018108	IDA
# ABL1	GO:0038083	IDA
# ABL1	GO:0042770	IDA
# ABL1	GO:0043065	IDA
# ABL1	GO:0046777	IDA
# ABL1	GO:0050731	IDA
# ABL1	GO:0051353	IDA
# ABL1	GO:0051444	IDA
# ABL1	GO:0070301	IDA
# ABL1	GO:0071103	IDA
# ABL1	GO:0071901	IDA
# ABL1	GO:1990051	IDA
# ABL1	GO:2001020	IDA
# AOC1	GO:0035874	IDA
# AOC1	GO:0042493	IDA
# AOC1	GO:0046677	IDA
# AOC1	GO:0055114	IDA
# AOC1	GO:0071280	IDA
# AOC1	GO:0071420	IDA
# AOC1	GO:0097185	IDA
# ABL2	GO:0018108	IDA
# ABL2	GO:0051353	IDA
# ACACB	GO:0006084	IDA
# ACACB	GO:0051289	IDA
# ACADM	GO:0033539	IDA
# ACADM	GO:0051791	IDA
# ACADM	GO:0051793	IDA
# ACADM	GO:0055114	IDA
# ACADS	GO:0033539	IDA
# ACADVL	GO:0033539	IDA
# ACAT1	GO:0006085	IDA
# ACAT1	GO:0015936	IDA
# ACAT1	GO:0015937	IDA
# ACAT1	GO:0046356	IDA
# ACAT1	GO:1902860	IDA
# ASIC1	GO:0035725	IDA
# ASIC1	GO:0071467	IDA
# ACHE	GO:0006581	IDA
# ACHE	GO:0007155	IDA
# ACLY	GO:0006085	IDA
# ACLY	GO:0006101	IDA
# ACLY	GO:0006107	IDA
# ACLY	GO:0008610	IDA
# ACO1	GO:0006101	IDA
# ACO1	GO:0010040	IDA
# ACR	GO:0007190	IDA
# ACO2	GO:0006099	IDA
# ACO2	GO:0006101	IDA
# ACOX1	GO:0006629	IDA
# ACPP	GO:0046085	IDA
# ACPP	GO:0051289	IDA
# ACTB	GO:0098974	IDA
# ACTC1	GO:0030048	IDA
# ACTN4	GO:0033209	IDA
# ACTN4	GO:0035357	IDA
# ACTN4	GO:0048384	IDA
# ACTN4	GO:0051272	IDA
# ACTL6A	GO:0006338	IDA
# ACTL6A	GO:0043967	IDA
# ACTL6A	GO:0043968	IDA
# ACTN2	GO:0030035	IDA
# ACTN2	GO:0043268	IDA
# ACTN2	GO:0051289	IDA
# ACTN2	GO:1901018	IDA
# ACVR1	GO:0006468	IDA
# ACVR1	GO:0007179	IDA
# ACVR1	GO:0010862	IDA
# ACVR1	GO:0018107	IDA
# ACVR1	GO:0030509	IDA
# ACVR1	GO:0032924	IDA
# ACVR1	GO:0045893	IDA
# ACVR1	GO:0045944	IDA
# ACVR1	GO:0060389	IDA
# ACVR1	GO:2000017	IDA
# ACVR1B	GO:0000082	IDA
# ACVR1B	GO:0006355	IDA
# ACVR1B	GO:0006468	IDA
# ACVR1B	GO:0007165	IDA
# ACVR1B	GO:0018107	IDA
# ACVR1B	GO:0030308	IDA
# ACVR1B	GO:0032924	IDA
# ACVR1B	GO:0032927	IDA
# ACVR1B	GO:0045648	IDA
# ACVR1B	GO:0046777	IDA
# ACVR1B	GO:1901165	IDA
# ACVR2A	GO:0030509	IDA
# ACVR2A	GO:0032927	IDA
# ACVR2A	GO:0045648	IDA
# ACVR2B	GO:0006355	IDA
# ACVR2B	GO:0007165	IDA
# ACVR2B	GO:0030509	IDA
# ACVR2B	GO:0032927	IDA
# ACVRL1	GO:0006468	IDA
# ACVRL1	GO:0007165	IDA
# ACVRL1	GO:0007179	IDA
# ACVRL1	GO:0010596	IDA
# ACVRL1	GO:0030308	IDA
# ACVRL1	GO:0030513	IDA
# ACVRL1	GO:0045893	IDA
# ACVRL1	GO:0045944	IDA
# ACVRL1	GO:0071560	IDA
# ADA	GO:0001666	IDA
# ADA	GO:0006154	IDA
# ADA	GO:0033632	IDA
# ADA	GO:0042110	IDA
# ADA	GO:0046103	IDA
# ADA	GO:0060169	IDA
# ADAM8	GO:0006954	IDA
# ADAM8	GO:0022407	IDA
# ADAM8	GO:0051044	IDA
# ADAM8	GO:0071456	IDA
# ADAM8	GO:2000391	IDA
# ADAM10	GO:0006509	IDA
# ADAM10	GO:0007162	IDA
# ADAM10	GO:0034612	IDA
# ADAM10	GO:0051089	IDA
# ADAR	GO:0006382	IDA
# ADAR	GO:0016553	IDA
# ADAR	GO:0031054	IDA
# ADAR	GO:0035280	IDA
# ADAR	GO:0035455	IDA
# ADAR	GO:0044387	IDA
# ADAR	GO:0045070	IDA
# ADARB1	GO:0006382	IDA
# ADARB1	GO:0008285	IDA
# ADARB1	GO:0030336	IDA
# ADARB1	GO:0044387	IDA
# ADARB1	GO:0051726	IDA
# ADCY5	GO:0006171	IDA
# ADCY5	GO:1904322	IDA
# ADCY6	GO:0006171	IDA
# ADCY6	GO:0007189	IDA
# ADCY6	GO:0007212	IDA
# ADCY6	GO:0071380	IDA
# ADCY6	GO:0071870	IDA
# ADCY6	GO:1904322	IDA
# ADCY7	GO:0006171	IDA
# ADCY7	GO:0071361	IDA
# ADCY9	GO:0006171	IDA
# ADCY9	GO:0007189	IDA
# ADCYAP1	GO:0007189	IDA
# ADCYAP1	GO:0007218	IDA
# ADCYAP1	GO:0008277	IDA
# ADCYAP1	GO:0031175	IDA
# ADCYAP1	GO:0032880	IDA
# ADCYAP1	GO:0043547	IDA
# ADCYAP1	GO:0045860	IDA
# ADCYAP1	GO:0045944	IDA
# ADCYAP1	GO:0070374	IDA
# ADCYAP1	GO:0071651	IDA
# ADD1	GO:0032092	IDA
# ADD1	GO:0051016	IDA
# ADD1	GO:0051017	IDA
# ADD1	GO:0071277	IDA
# ADD1	GO:1903142	IDA
# ADD1	GO:1903393	IDA
# ADD2	GO:0032092	IDA
# ADD2	GO:0051016	IDA
# ADD2	GO:0051017	IDA
# ADD2	GO:0065003	IDA
# ADH1B	GO:0006069	IDA
# ADH1C	GO:0006069	IDA
# ADH4	GO:0001523	IDA
# ADH4	GO:0006066	IDA
# ADH4	GO:0006069	IDA
# ADH4	GO:0006081	IDA
# ADH4	GO:0042572	IDA
# ADH5	GO:0051775	IDA
# ADH6	GO:0006069	IDA
# ADH6	GO:0045471	IDA
# ADH7	GO:0001523	IDA
# ADH7	GO:0006069	IDA
# ADH7	GO:0009617	IDA
# ADH7	GO:0010430	IDA
# ADH7	GO:0045471	IDA
# ADH7	GO:0055114	IDA
# ADM	GO:0001570	IDA
# ADM	GO:0002031	IDA
# ADM	GO:0003073	IDA
# ADM	GO:0007189	IDA
# ADM	GO:0010460	IDA
# ADM	GO:0031623	IDA
# ADM	GO:0035809	IDA
# ADM	GO:0045906	IDA
# ADM	GO:1990410	IDA
# ADORA2A	GO:0007189	IDA
# ADPRH	GO:0051725	IDA
# PARP1	GO:0006471	IDA
# PARP1	GO:0006915	IDA
# PARP1	GO:0018312	IDA
# PARP1	GO:0018424	IDA
# PARP1	GO:0030592	IDA
# PARP1	GO:0032869	IDA
# PARP1	GO:0045944	IDA
# PARP1	GO:0050790	IDA
# PARP1	GO:0070212	IDA
# PARP1	GO:0070213	IDA
# PARP1	GO:1905168	IDA
# PARP1	GO:1990966	IDA
# PARP4	GO:0006464	IDA
# PARP4	GO:0051972	IDA
# ADRA1B	GO:0043410	IDA
# ADRA1A	GO:0043410	IDA
# ADRA2A	GO:0001819	IDA
# ADRA2A	GO:0007186	IDA
# ADRA2A	GO:0032147	IDA
# ADRA2A	GO:0032148	IDA
# ADRA2A	GO:0035624	IDA
# ADRA2A	GO:0043406	IDA
# ADRA2A	GO:0043410	IDA
# ADRA2A	GO:0045741	IDA
# ADRA2A	GO:0051044	IDA
# ADRA2A	GO:0071875	IDA
# ADRA2A	GO:0071881	IDA
# ADRA2A	GO:0071882	IDA
# ADRA2B	GO:0007186	IDA
# ADRA2B	GO:0032148	IDA
# ADRA2B	GO:0035624	IDA
# ADRA2B	GO:0043410	IDA
# ADRA2B	GO:0045666	IDA
# ADRA2B	GO:0071875	IDA
# ADRA2C	GO:0007186	IDA
# ADRA2C	GO:0032148	IDA
# ADRA2C	GO:0035624	IDA
# ADRA2C	GO:0043410	IDA
# ADRA2C	GO:0045666	IDA
# ADRA2C	GO:0071875	IDA
# ADRB1	GO:0043547	IDA
# ADRB1	GO:0071880	IDA
# ADRB2	GO:0002032	IDA
# ADRB2	GO:0006898	IDA
# ADRB2	GO:0007190	IDA
# ADRB2	GO:0043410	IDA
# ADRB2	GO:0071875	IDA
# ADRB2	GO:1901098	IDA
# ADRB2	GO:1904504	IDA
# ADRB3	GO:0007190	IDA
# ADRB3	GO:0043410	IDA
# GRK2	GO:0007217	IDA
# GRK2	GO:0031623	IDA
# GRK3	GO:0031623	IDA
# ADSL	GO:0006167	IDA
# ADSL	GO:0051262	IDA
# ADSS	GO:0006167	IDA
# AP2A1	GO:1900126	IDA
# AEBP1	GO:1904026	IDA
# TLE5	GO:0032091	IDA
# TLE5	GO:0045892	IDA
# TLE5	GO:0070555	IDA
# TLE5	GO:0090090	IDA
# AFM	GO:0050821	IDA
# AFM	GO:0051180	IDA
# AGA	GO:0006517	IDA
# AGER	GO:0001914	IDA
# AGER	GO:0010255	IDA
# AGER	GO:0032693	IDA
# AGER	GO:0051092	IDA
# AGER	GO:2000514	IDA
# AGRP	GO:0007218	IDA
# AGRP	GO:0060259	IDA
# JAG1	GO:0001953	IDA
# JAG1	GO:0022408	IDA
# JAG1	GO:0030336	IDA
# AGT	GO:0003014	IDA
# AGT	GO:0007186	IDA
# AGT	GO:0010595	IDA
# AGT	GO:0010873	IDA
# AGT	GO:0014068	IDA
# AGT	GO:0032270	IDA
# AGT	GO:0045742	IDA
# AGT	GO:0045893	IDA
# AGT	GO:0050731	IDA
# AGT	GO:0051387	IDA
# AGT	GO:0090190	IDA
# AGT	GO:2001238	IDA
# AGTR1	GO:0007186	IDA
# AGTR1	GO:0007204	IDA
# AGTR1	GO:0007266	IDA
# AGTR1	GO:0019229	IDA
# AGTR1	GO:0019722	IDA
# AGTR1	GO:0038166	IDA
# AGTR1	GO:0051482	IDA
# AGTR1	GO:0060326	IDA
# AGTR1	GO:0086097	IDA
# AGTR2	GO:0007166	IDA
# AGTR2	GO:0032516	IDA
# AGTR2	GO:0042311	IDA
# AGXT	GO:0009436	IDA
# AGXT	GO:0019265	IDA
# AGXT	GO:0019448	IDA
# AGXT	GO:0042853	IDA
# NR0B1	GO:0006694	IDA
# NR0B1	GO:0008104	IDA
# NR0B1	GO:0033144	IDA
# NR0B1	GO:0045892	IDA
# AHR	GO:0006355	IDA
# AHR	GO:0006357	IDA
# AHR	GO:0006366	IDA
# AHR	GO:0009410	IDA
# AHR	GO:0009636	IDA
# AHR	GO:0010468	IDA
# AHR	GO:0019933	IDA
# AHR	GO:0030888	IDA
# AHR	GO:0071320	IDA
# AHR	GO:1904322	IDA
# AHR	GO:1904613	IDA
# AHSG	GO:0006953	IDA
# AHSG	GO:0050766	IDA
# AIF1	GO:0008284	IDA
# AIF1	GO:0030041	IDA
# AIF1	GO:0030335	IDA
# AIF1	GO:0034599	IDA
# AIF1	GO:0042102	IDA
# AIF1	GO:0048661	IDA
# AIF1	GO:0048662	IDA
# AIF1	GO:0050921	IDA
# AIF1	GO:0051017	IDA
# AIF1	GO:0071672	IDA
# AIF1	GO:0071673	IDA
# AIF1	GO:0071677	IDA
# AIF1	GO:0090026	IDA
# AIF1	GO:0090197	IDA
# AIF1	GO:0090271	IDA
# AIF1	GO:1900087	IDA
# AIF1	GO:2000406	IDA
# AIF1	GO:2000778	IDA
# AK1	GO:0006165	IDA
# AK1	GO:0009142	IDA
# AK4	GO:0006165	IDA
# AK4	GO:0009142	IDA
# AK4	GO:0046033	IDA
# AK4	GO:0046034	IDA
# AK4	GO:0046039	IDA
# AKT1	GO:0001934	IDA
# AKT1	GO:0006468	IDA
# AKT1	GO:0007173	IDA
# AKT1	GO:0016310	IDA
# AKT1	GO:0018105	IDA
# AKT1	GO:0018107	IDA
# AKT1	GO:0030307	IDA
# AKT1	GO:0032079	IDA
# AKT1	GO:0033138	IDA
# AKT1	GO:0035556	IDA
# AKT1	GO:0035655	IDA
# AKT1	GO:0043066	IDA
# AKT1	GO:0043536	IDA
# AKT1	GO:0048661	IDA
# AKT1	GO:0051091	IDA
# AKT1	GO:0070141	IDA
# AKT2	GO:0030335	IDA
# ALAD	GO:0006783	IDA
# ALAD	GO:1901799	IDA
# ALAS2	GO:0001666	IDA
# ALB	GO:0009267	IDA
# ALB	GO:0032460	IDA
# ALB	GO:0043066	IDA
# ALB	GO:0051659	IDA
# ABCD1	GO:0006635	IDA
# ABCD1	GO:0007031	IDA
# ABCD1	GO:0042760	IDA
# ALDH1A1	GO:0055114	IDA
# ALDH3A1	GO:0006081	IDA
# ALDH3A1	GO:0055114	IDA
# ALDH1A3	GO:0002138	IDA
# ALDH1A3	GO:0042573	IDA
# ALDH1A3	GO:0042574	IDA
# ALDH1A3	GO:0051289	IDA
# ALDH3B1	GO:0034599	IDA
# ALDH3B1	GO:0046185	IDA
# ALDH3B1	GO:0055114	IDA
# ALDH9A1	GO:0006081	IDA
# ALDH9A1	GO:0042136	IDA
# ALDH9A1	GO:0055114	IDA
# ALDH3A2	GO:0006081	IDA
# ALDH3A2	GO:0046458	IDA
# ALDH3A2	GO:0055114	IDA
# ABCD2	GO:0000038	IDA
# ABCD2	GO:0032000	IDA
# ALDOA	GO:0008360	IDA
# ALDOA	GO:0030388	IDA
# ALDOB	GO:0006096	IDA
# ALDOB	GO:0006116	IDA
# ALDOB	GO:0030388	IDA
# ALDOC	GO:0030388	IDA
# AKR1B1	GO:0055114	IDA
# AKR1B1	GO:0071475	IDA
# ALK	GO:0016310	IDA
# ALK	GO:0046777	IDA
# ALOX12	GO:0019369	IDA
# ALOX12	GO:0019372	IDA
# ALOX12	GO:0043651	IDA
# ALOX12	GO:1901751	IDA
# ALOX12	GO:2001303	IDA
# ALOX12	GO:2001306	IDA
# ALOX5	GO:0019370	IDA
# ALOX5AP	GO:0019370	IDA
# ALOX5AP	GO:0071277	IDA
# ALOX12B	GO:0006665	IDA
# ALOX12B	GO:0019372	IDA
# ALOX12B	GO:0043410	IDA
# ALOX12B	GO:0055114	IDA
# ALOX15	GO:0010811	IDA
# ALOX15	GO:0019369	IDA
# ALOX15	GO:0019372	IDA
# ALOX15	GO:0071277	IDA
# ALOX15B	GO:0008285	IDA
# ALOX15B	GO:0019369	IDA
# ALOX15B	GO:0045786	IDA
# ALOX15B	GO:0045926	IDA
# AMFR	GO:0000209	IDA
# AMFR	GO:0030433	IDA
# AMFR	GO:0051259	IDA
# AMFR	GO:0051865	IDA
# AMFR	GO:0070936	IDA
# AMH	GO:0001880	IDA
# BIN1	GO:0033292	IDA
# BIN1	GO:0043065	IDA
# BIN1	GO:0071156	IDA
# AMY2A	GO:0016052	IDA
# ANG	GO:0001525	IDA
# ANG	GO:0001666	IDA
# ANG	GO:0001938	IDA
# ANG	GO:0006651	IDA
# ANG	GO:0009725	IDA
# ANG	GO:0042327	IDA
# ANG	GO:0048662	IDA
# ANG	GO:0050714	IDA
# ANGPT1	GO:0002040	IDA
# ANGPT1	GO:0002092	IDA
# ANGPT1	GO:0007162	IDA
# ANGPT1	GO:0007171	IDA
# ANGPT1	GO:0010595	IDA
# ANGPT1	GO:0014842	IDA
# ANGPT1	GO:0030210	IDA
# ANGPT1	GO:0031398	IDA
# ANGPT1	GO:0034394	IDA
# ANGPT1	GO:0043066	IDA
# ANGPT1	GO:0043116	IDA
# ANGPT1	GO:0043536	IDA
# ANGPT1	GO:0048014	IDA
# ANGPT1	GO:0050731	IDA
# ANGPT1	GO:0050918	IDA
# ANGPT1	GO:0051897	IDA
# ANGPT1	GO:0070374	IDA
# ANGPT1	GO:2000352	IDA
# ANGPT2	GO:0043537	IDA
# ANGPT2	GO:0048014	IDA
# ANGPT2	GO:0050928	IDA
# ANK1	GO:0006888	IDA
# ANXA1	GO:0002548	IDA
# ANXA1	GO:0007187	IDA
# ANXA1	GO:0008360	IDA
# ANXA1	GO:0018149	IDA
# ANXA1	GO:0030216	IDA
# ANXA1	GO:0031340	IDA
# ANXA1	GO:0031532	IDA
# ANXA1	GO:0032743	IDA
# ANXA1	GO:0035924	IDA
# ANXA1	GO:0042102	IDA
# ANXA1	GO:0045627	IDA
# ANXA1	GO:0045629	IDA
# ANXA1	GO:0071385	IDA
# ANXA1	GO:0071621	IDA
# ANXA1	GO:0090050	IDA
# ANXA1	GO:0090303	IDA
# ANXA2	GO:0001921	IDA
# ANXA2	GO:0031340	IDA
# ANXA2	GO:0032804	IDA
# ANXA2	GO:0036035	IDA
# ANXA2	GO:0051290	IDA
# ANXA2	GO:1905581	IDA
# ANXA2	GO:1905597	IDA
# ANXA2	GO:1905602	IDA
# ANXA3	GO:0006909	IDA
# ANXA3	GO:0010595	IDA
# ANXA3	GO:0042742	IDA
# ANXA3	GO:0043312	IDA
# ANXA3	GO:0045766	IDA
# ANXA3	GO:0051091	IDA
# ANXA4	GO:0006357	IDA
# ANXA4	GO:0032088	IDA
# ANXA11	GO:0051592	IDA
# AOAH	GO:0006631	IDA
# AOAH	GO:0009104	IDA
# AOX1	GO:0017144	IDA
# AOX1	GO:0055114	IDA
# APAF1	GO:0006919	IDA
# APAF1	GO:0008635	IDA
# APBB1	GO:0006974	IDA
# APBB1	GO:0043065	IDA
# APBB1	GO:0045893	IDA
# APC	GO:0006974	IDA
# APC	GO:0007026	IDA
# APC	GO:0007050	IDA
# APC	GO:0008285	IDA
# APC	GO:0045736	IDA
# APC	GO:0065003	IDA
# APCS	GO:0044869	IDA
# APCS	GO:0044871	IDA
# APCS	GO:0045087	IDA
# APCS	GO:0045656	IDA
# APCS	GO:0046597	IDA
# APCS	GO:0048525	IDA
# APCS	GO:1903016	IDA
# APCS	GO:1903019	IDA
# AIRE	GO:0006355	IDA
# AIRE	GO:0045893	IDA
# APEH	GO:0006508	IDA
# APEH	GO:0050435	IDA
# APEX1	GO:0000723	IDA
# APEX1	GO:0006281	IDA
# APEX1	GO:0006284	IDA
# APEX1	GO:0042981	IDA
# APEX1	GO:0080111	IDA
# APEX1	GO:0097698	IDA
# BIRC2	GO:0000209	IDA
# BIRC2	GO:0043066	IDA
# BIRC2	GO:0043161	IDA
# BIRC2	GO:0051726	IDA
# BIRC2	GO:1902523	IDA
# BIRC2	GO:1902524	IDA
# BIRC2	GO:1902527	IDA
# BIRC3	GO:0031398	IDA
# XIAP	GO:0031398	IDA
# XIAP	GO:0043154	IDA
# XIAP	GO:1902530	IDA
# BIRC5	GO:0006468	IDA
# BIRC5	GO:0043066	IDA
# APLP1	GO:0071874	IDA
# APLP1	GO:0106072	IDA
# APOA1	GO:0002740	IDA
# APOA1	GO:0006656	IDA
# APOA1	GO:0007186	IDA
# APOA1	GO:0007229	IDA
# APOA1	GO:0010804	IDA
# APOA1	GO:0010873	IDA
# APOA1	GO:0010875	IDA
# APOA1	GO:0010903	IDA
# APOA1	GO:0018158	IDA
# APOA1	GO:0018206	IDA
# APOA1	GO:0030301	IDA
# APOA1	GO:0032489	IDA
# APOA1	GO:0033344	IDA
# APOA1	GO:0033700	IDA
# APOA1	GO:0034115	IDA
# APOA1	GO:0034375	IDA
# APOA1	GO:0034380	IDA
# APOA1	GO:0035025	IDA
# APOA1	GO:0042632	IDA
# APOA1	GO:0050713	IDA
# APOA1	GO:0050728	IDA
# APOA1	GO:0050766	IDA
# APOA1	GO:0050821	IDA
# APOA1	GO:0050919	IDA
# APOA1	GO:0051345	IDA
# APOA1	GO:0051496	IDA
# APOA1	GO:0055091	IDA
# APOA1	GO:0060354	IDA
# APOA1	GO:0060761	IDA
# APOA1	GO:0070328	IDA
# APOA1	GO:1900026	IDA
# APOA1	GO:1902995	IDA
# APOA2	GO:0002740	IDA
# APOA2	GO:0006656	IDA
# APOA2	GO:0009395	IDA
# APOA2	GO:0009749	IDA
# APOA2	GO:0010873	IDA
# APOA2	GO:0010903	IDA
# APOA2	GO:0018158	IDA
# APOA2	GO:0018206	IDA
# APOA2	GO:0031647	IDA
# APOA2	GO:0033344	IDA
# APOA2	GO:0033700	IDA
# APOA2	GO:0034370	IDA
# APOA2	GO:0034374	IDA
# APOA2	GO:0034375	IDA
# APOA2	GO:0034380	IDA
# APOA2	GO:0034384	IDA
# APOA2	GO:0042632	IDA
# APOA2	GO:0043691	IDA
# APOA2	GO:0045416	IDA
# APOA2	GO:0046340	IDA
# APOA2	GO:0050766	IDA
# APOA2	GO:0050821	IDA
# APOA2	GO:0050995	IDA
# APOA2	GO:0050996	IDA
# APOA2	GO:0060192	IDA
# APOA2	GO:0060621	IDA
# APOA2	GO:0060695	IDA
# APOA4	GO:0002227	IDA
# APOA4	GO:0006869	IDA
# APOA4	GO:0006982	IDA
# APOA4	GO:0007159	IDA
# APOA4	GO:0008203	IDA
# APOA4	GO:0010873	IDA
# APOA4	GO:0010898	IDA
# APOA4	GO:0016042	IDA
# APOA4	GO:0019430	IDA
# APOA4	GO:0032374	IDA
# APOA4	GO:0033344	IDA
# APOA4	GO:0033700	IDA
# APOA4	GO:0034372	IDA
# APOA4	GO:0034445	IDA
# APOA4	GO:0042632	IDA
# APOA4	GO:0042744	IDA
# APOA4	GO:0043691	IDA
# APOA4	GO:0045723	IDA
# APOA4	GO:0046470	IDA
# APOA4	GO:0051006	IDA
# APOA4	GO:0055088	IDA
# APOB	GO:0010744	IDA
# APOB	GO:0010884	IDA
# APOB	GO:0010886	IDA
# APOC1	GO:0010900	IDA
# APOC1	GO:0010916	IDA
# APOC1	GO:0032375	IDA
# APOC1	GO:0033344	IDA
# APOC1	GO:0033700	IDA
# APOC1	GO:0034369	IDA
# APOC1	GO:0034382	IDA
# APOC1	GO:0045717	IDA
# APOC1	GO:0045833	IDA
# APOC1	GO:0048261	IDA
# APOC1	GO:0050995	IDA
# APOC1	GO:0051005	IDA
# APOC2	GO:0010518	IDA
# APOC2	GO:0010898	IDA
# APOC2	GO:0010916	IDA
# APOC2	GO:0033344	IDA
# APOC2	GO:0033700	IDA
# APOC2	GO:0034382	IDA
# APOC2	GO:0045723	IDA
# APOC2	GO:0045833	IDA
# APOC2	GO:0048261	IDA
# APOC2	GO:0051006	IDA
# APOC2	GO:0060697	IDA
# APOC3	GO:0007186	IDA
# APOC3	GO:0010897	IDA
# APOC3	GO:0010903	IDA
# APOC3	GO:0010916	IDA
# APOC3	GO:0019433	IDA
# APOC3	GO:0032489	IDA
# APOC3	GO:0033344	IDA
# APOC3	GO:0033700	IDA
# APOC3	GO:0034382	IDA
# APOC3	GO:0045717	IDA
# APOC3	GO:0045833	IDA
# APOC3	GO:0048261	IDA
# APOC3	GO:0050995	IDA
# APOC3	GO:0051005	IDA
# APOD	GO:0000302	IDA
# APOD	GO:0006006	IDA
# APOD	GO:0006629	IDA
# APOD	GO:0010642	IDA
# APOD	GO:0042308	IDA
# APOD	GO:0048662	IDA
# APOD	GO:0060588	IDA
# APOD	GO:0071638	IDA
# APOD	GO:1900016	IDA
# APOD	GO:2000405	IDA
# APOE	GO:0001937	IDA
# APOE	GO:0006641	IDA
# APOE	GO:0006898	IDA
# APOE	GO:0007186	IDA
# APOE	GO:0007263	IDA
# APOE	GO:0008203	IDA
# APOE	GO:0010544	IDA
# APOE	GO:0010873	IDA
# APOE	GO:0010875	IDA
# APOE	GO:0010976	IDA
# APOE	GO:0010977	IDA
# APOE	GO:0015909	IDA
# APOE	GO:0017038	IDA
# APOE	GO:0019934	IDA
# APOE	GO:0030195	IDA
# APOE	GO:0031175	IDA
# APOE	GO:0032462	IDA
# APOE	GO:0032489	IDA
# APOE	GO:0032805	IDA
# APOE	GO:0033344	IDA
# APOE	GO:0033700	IDA
# APOE	GO:0034372	IDA
# APOE	GO:0034380	IDA
# APOE	GO:0034382	IDA
# APOE	GO:0034384	IDA
# APOE	GO:0034447	IDA
# APOE	GO:0042158	IDA
# APOE	GO:0042632	IDA
# APOE	GO:0042982	IDA
# APOE	GO:0043407	IDA
# APOE	GO:0043537	IDA
# APOE	GO:0043691	IDA
# APOE	GO:0045541	IDA
# APOE	GO:0045807	IDA
# APOE	GO:0046889	IDA
# APOE	GO:0051000	IDA
# APOE	GO:0051044	IDA
# APOE	GO:0055089	IDA
# APOE	GO:0060999	IDA
# APOE	GO:0071831	IDA
# APOE	GO:0090090	IDA
# APOE	GO:0097113	IDA
# APOE	GO:0097114	IDA
# APOE	GO:1900221	IDA
# APOE	GO:1900272	IDA
# APOE	GO:1901215	IDA
# APOE	GO:1901628	IDA
# APOE	GO:1901630	IDA
# APOE	GO:1902430	IDA
# APOE	GO:1902952	IDA
# APOE	GO:1902995	IDA
# APOE	GO:1903002	IDA
# APOE	GO:1905855	IDA
# APOE	GO:1905860	IDA
# APOE	GO:1905890	IDA
# APOE	GO:1905906	IDA
# APOH	GO:0001937	IDA
# APOH	GO:0006641	IDA
# APOH	GO:0007597	IDA
# APOH	GO:0010596	IDA
# APOH	GO:0016525	IDA
# APOH	GO:0030195	IDA
# APOH	GO:0031639	IDA
# APOH	GO:0033033	IDA
# APOH	GO:0034392	IDA
# APOH	GO:0051006	IDA
# APOH	GO:0051917	IDA
# APOH	GO:0051918	IDA
# APP	GO:0001934	IDA
# APP	GO:0008285	IDA
# APP	GO:1905606	EXP
# APP	GO:1905606	IDA
# KLK3	GO:0002778	IDA
# FAS	GO:0006915	IDA
# FAS	GO:0043065	IDA
# FASLG	GO:0000122	IDA
# FASLG	GO:0008625	IDA
# FASLG	GO:0016525	IDA
# FASLG	GO:0043065	IDA
# FASLG	GO:0070231	IDA
# FASLG	GO:0070266	IDA
# FASLG	GO:0097190	IDA
# FASLG	GO:0097191	IDA
# FASLG	GO:0097527	IDA
# FASLG	GO:1903514	IDA
# FASLG	GO:2000353	IDA
# AQP1	GO:0003097	IDA
# AQP1	GO:0006833	IDA
# AQP1	GO:0015670	IDA
# AQP1	GO:0015696	IDA
# AQP1	GO:0015793	IDA
# AQP1	GO:0019725	IDA
# AQP1	GO:0019934	IDA
# AQP1	GO:0030185	IDA
# AQP1	GO:0034644	IDA
# AQP1	GO:0035377	IDA
# AQP1	GO:0035378	IDA
# AQP1	GO:0042493	IDA
# AQP1	GO:0043066	IDA
# AQP1	GO:0048146	IDA
# AQP1	GO:0070301	IDA
# AQP1	GO:0071241	IDA
# AQP1	GO:0071260	IDA
# AQP1	GO:0071280	IDA
# AQP1	GO:0071288	IDA
# AQP1	GO:0071300	IDA
# AQP1	GO:0071320	IDA
# AQP1	GO:0071456	IDA
# AQP1	GO:0071472	IDA
# AQP1	GO:0071549	IDA
# AQP1	GO:0071732	IDA
# AQP2	GO:0006833	IDA
# AQP2	GO:0015793	IDA
# AQP2	GO:0051289	IDA
# AQP2	GO:0071280	IDA
# AQP2	GO:0071288	IDA
# AQP3	GO:0002684	IDA
# AQP3	GO:0006833	IDA
# AQP3	GO:0015793	IDA
# AQP3	GO:0032526	IDA
# AQP3	GO:0071456	IDA
# AQP4	GO:0006833	IDA
# AQP4	GO:0051289	IDA
# AQP4	GO:0071346	IDA
# AQP5	GO:0006833	IDA
# AQP5	GO:0015670	IDA
# AQP5	GO:0051289	IDA
# AQP5	GO:0071476	IDA
# AQP7	GO:0006833	IDA
# AQP7	GO:0015793	IDA
# AQP9	GO:0006833	IDA
# AQP9	GO:0006863	IDA
# AQP9	GO:0010033	IDA
# AQP9	GO:0015791	IDA
# AQP9	GO:0015793	IDA
# AQP9	GO:0015837	IDA
# AQP9	GO:0015855	IDA
# AQP9	GO:0046689	IDA
# AR	GO:0006351	IDA
# AR	GO:0008284	IDA
# AR	GO:0010628	IDA
# AR	GO:0030521	IDA
# AR	GO:0030522	IDA
# AR	GO:0045720	IDA
# AR	GO:0045726	IDA
# AR	GO:0045893	IDA
# AR	GO:0045944	IDA
# AR	GO:0045945	IDA
# AR	GO:0051259	IDA
# AR	GO:1903076	IDA
# AR	GO:2001237	IDA
# ARAF	GO:0033138	IDA
# ARAF	GO:0043066	IDA
# TRIM23	GO:0016567	IDA
# AREG	GO:0007173	IDA
# AREG	GO:0007186	IDA
# ARF4	GO:0006471	IDA
# ARF4	GO:0016477	IDA
# ARF4	GO:0031584	IDA
# ARF4	GO:0043066	IDA
# ARF4	GO:0045944	IDA
# ARF4	GO:0060996	IDA
# ARF4	GO:2000377	IDA
# ARF6	GO:0030866	IDA
# ARF6	GO:0032456	IDA
# ARF6	GO:0035020	IDA
# ARF6	GO:0051489	IDA
# ARF6	GO:0097178	IDA
# ARG1	GO:0042130	IDA
# ARG2	GO:2000774	IDA
# RHOA	GO:0007266	IDA
# RHOA	GO:0016477	IDA
# RHOA	GO:0032956	IDA
# RHOA	GO:0035385	IDA
# RHOA	GO:0036089	IDA
# RHOA	GO:0051496	IDA
# RHOA	GO:0060193	IDA
# RHOA	GO:0071222	IDA
# RHOA	GO:0071902	IDA
# RHOA	GO:1905274	EXP
# RHOB	GO:0008333	IDA
# RHOB	GO:0030336	IDA
# RHOB	GO:0070301	IDA
# RHOB	GO:0071479	IDA
# RHOC	GO:0000281	IDA
# RHOC	GO:0043297	IDA
# RHOC	GO:0060193	IDA
# RHOG	GO:0007266	IDA
# RHOG	GO:0016601	IDA
# RHOG	GO:0030036	IDA
# RHOG	GO:0045893	IDA
# ARHGAP1	GO:0007264	IDA
# ARHGDIB	GO:0035023	IDA
# ARHGDIB	GO:1901164	IDA
# RHOH	GO:0043124	IDA
# ARL1	GO:0009404	IDA
# ARL1	GO:0031584	IDA
# PHOX2A	GO:0045944	IDA
# ARL2	GO:0031116	IDA
# ARL2	GO:0034260	IDA
# ARL2	GO:0051457	IDA
# ARL3	GO:0007264	IDA
# ARNT	GO:0001666	IDA
# ARNT	GO:0010575	IDA
# ARNT	GO:0043619	IDA
# ARNT	GO:0045893	IDA
# ARNT	GO:0046886	IDA
# ARNTL	GO:0032922	IDA
# ARNTL	GO:0045893	IDA
# ARNTL	GO:0045944	IDA
# ARNTL	GO:0051775	IDA
# ARRB1	GO:0031397	IDA
# ARRB1	GO:0032088	IDA
# ARRB1	GO:0032715	IDA
# ARRB1	GO:0032717	IDA
# ARRB1	GO:0070374	IDA
# ARRB2	GO:0002031	IDA
# ARRB2	GO:0006366	IDA
# ARRB2	GO:0007179	IDA
# ARRB2	GO:0031397	IDA
# ARRB2	GO:0031623	IDA
# ARRB2	GO:0032088	IDA
# ARRB2	GO:0060765	IDA
# ARRB2	GO:0070374	IDA
# ASAH1	GO:0046512	IDA
# ASAH1	GO:0046513	IDA
# ASAH1	GO:0046514	IDA
# ASCL1	GO:0000122	IDA
# ASCL1	GO:0007219	IDA
# ASCL1	GO:0022008	IDA
# ASCL1	GO:0045665	IDA
# ASCL1	GO:0045892	IDA
# ASCL1	GO:0045944	IDA
# ASCL2	GO:0000122	IDA
# ASCL2	GO:0006351	IDA
# ASMT	GO:0030187	IDA
# ASNA1	GO:0071816	IDA
# ASNS	GO:0006529	IDA
# ASNS	GO:0042149	IDA
# ASNS	GO:0045931	IDA
# ASPH	GO:0045862	IDA
# ASPH	GO:0097202	IDA
# ASS1	GO:0007623	IDA
# ZFHX3	GO:0000122	IDA
# ZFHX3	GO:0045893	IDA
# ZFHX3	GO:0071559	IDA
# ATF1	GO:0045944	IDA
# ATF3	GO:0000122	IDA
# ATF3	GO:0045944	IDA
# ATF3	GO:1990440	IDA
# ATF4	GO:0034976	IDA
# ATF4	GO:0045893	IDA
# ATF4	GO:0045944	IDA
# ATF4	GO:1990440	IDA
# ATM	GO:0006468	IDA
# ATM	GO:0006974	IDA
# ATM	GO:0006975	IDA
# ATM	GO:0010212	IDA
# ATM	GO:0018105	IDA
# ATM	GO:0046777	IDA
# ATM	GO:0071044	IDA
# ATM	GO:0071480	IDA
# ATM	GO:0071481	IDA
# ATM	GO:0071500	IDA
# ATP1A1	GO:0006883	IDA
# ATP1A1	GO:0030007	IDA
# ATP1A1	GO:0036376	IDA
# ATP1A1	GO:0071383	IDA
# ATP1A1	GO:0086009	IDA
# ATP1A1	GO:1903416	IDA
# ATP1A1	GO:1990573	IDA
# ATP1A2	GO:0006883	IDA
# ATP1A2	GO:0030007	IDA
# ATP1A2	GO:0036376	IDA
# ATP1A2	GO:0071383	IDA
# ATP1A2	GO:1990573	IDA
# ATP1A3	GO:0006883	IDA
# ATP1A3	GO:0030007	IDA
# ATP1A3	GO:0036376	IDA
# ATP1A3	GO:1990573	IDA
# ATP1A4	GO:0030317	IDA
# ATP1A4	GO:0030641	IDA
# ATP1B1	GO:0006883	IDA
# ATP1B1	GO:0030007	IDA
# ATP1B1	GO:0032781	IDA
# ATP1B1	GO:0036376	IDA
# ATP1B1	GO:0046034	IDA
# ATP1B1	GO:0050821	IDA
# ATP1B1	GO:0072659	IDA
# ATP1B1	GO:0086009	IDA
# ATP1B1	GO:1901018	IDA
# ATP1B1	GO:1903278	IDA
# ATP1B1	GO:1903288	IDA
# ATP1B1	GO:1990573	IDA
# ATP1B2	GO:0006883	IDA
# ATP1B2	GO:0030007	IDA
# ATP1B2	GO:0032781	IDA
# ATP1B2	GO:0036376	IDA
# ATP1B2	GO:0050821	IDA
# ATP1B2	GO:0086009	IDA
# ATP1B2	GO:1901018	IDA
# ATP1B2	GO:1903278	IDA
# ATP1B2	GO:1903288	IDA
# ATP1B2	GO:1990573	IDA
# ATP1B3	GO:0006883	IDA
# ATP1B3	GO:0030007	IDA
# ATP1B3	GO:0032781	IDA
# ATP1B3	GO:0036376	IDA
# ATP1B3	GO:0050821	IDA
# ATP1B3	GO:0072659	IDA
# ATP1B3	GO:0086009	IDA
# ATP1B3	GO:1901018	IDA
# ATP1B3	GO:1903278	IDA
# ATP1B3	GO:1903288	IDA
# ATP1B3	GO:1990573	IDA
# ATP2A1	GO:0031448	IDA
# ATP2A1	GO:0090076	IDA
# ATP2A2	GO:0032469	IDA
# ATP2A2	GO:0032470	IDA
# ATP2A2	GO:0070588	IDA
# ATP2A2	GO:1903515	IDA
# ATP2B1	GO:0051480	IDA
# ATP2B1	GO:1990034	IDA
# ATP2B2	GO:0030182	IDA
# ATP2B3	GO:0051480	IDA
# ATP2B3	GO:1990034	IDA
# ATP2B4	GO:0006874	IDA
# ATP2B4	GO:0010751	IDA
# ATP2B4	GO:0033138	IDA
# ATP2B4	GO:0045019	IDA
# ATP2B4	GO:0051001	IDA
# ATP2B4	GO:0070885	IDA
# ATP2B4	GO:0071872	IDA
# ATP2B4	GO:0098736	IDA
# ATP2B4	GO:0140199	IDA
# ATP2B4	GO:1900082	IDA
# ATP2B4	GO:1903249	IDA
# ATP2B4	GO:2000481	IDA
# ATP7A	GO:0051353	IDA
# ATP7B	GO:0006825	IDA
# ATP7B	GO:0015677	IDA
# ATP7B	GO:0046688	IDA
# ATP7B	GO:0051208	IDA
# ATR	GO:0000077	IDA
# ATR	GO:0006974	IDA
# ATR	GO:0018105	IDA
# ATR	GO:0046777	IDA
# ATR	GO:0071480	IDA
# ATRX	GO:0006334	IDA
# ATRX	GO:0006338	IDA
# AVP	GO:0007165	IDA
# AVP	GO:0010628	IDA
# AVP	GO:0033138	IDA
# AVP	GO:0043066	IDA
# AVP	GO:0043154	IDA
# AVP	GO:0070371	IDA
# AVP	GO:0070528	IDA
# AVP	GO:0090201	IDA
# AXL	GO:0001961	IDA
# AXL	GO:0006909	IDA
# AXL	GO:0032689	IDA
# AXL	GO:0032825	IDA
# AXL	GO:0035457	IDA
# AXL	GO:0071222	IDA
# AXL	GO:2000669	IDA
# AZGP1	GO:0001580	IDA
# AZGP1	GO:0007155	IDA
# AZU1	GO:0006508	IDA
# AZU1	GO:0008347	IDA
# AZU1	GO:0010800	IDA
# AZU1	GO:0042535	IDA
# AZU1	GO:0045785	IDA
# AZU1	GO:0045860	IDA
# AZU1	GO:0050725	IDA
# AZU1	GO:0050754	IDA
# AZU1	GO:0050766	IDA
# AZU1	GO:0070944	IDA
# B2M	GO:0002726	IDA
# B2M	GO:1900121	IDA
# BAAT	GO:0002152	IDA
# BAAT	GO:0006544	IDA
# BAAT	GO:0006637	IDA
# BAAT	GO:0006699	IDA
# BAAT	GO:0019530	IDA
# BACH1	GO:0000122	IDA
# BACH1	GO:0061418	IDA
# BAD	GO:0006915	IDA
# BAD	GO:0043065	IDA
# BAD	GO:0043280	IDA
# BAD	GO:0045862	IDA
# BAD	GO:0046931	IDA
# BAD	GO:0071316	IDA
# BAD	GO:0097202	IDA
# BAG1	GO:0051085	IDA
# ADGRB1	GO:0010596	IDA
# ADGRB1	GO:0016525	IDA
# ADGRB2	GO:0007186	IDA
# ADGRB3	GO:0007520	IDA
# BAK1	GO:0001836	IDA
# BAK1	GO:0006915	IDA
# BAK1	GO:0010248	IDA
# BAK1	GO:0043496	IDA
# BAK1	GO:0043497	IDA
# BAK1	GO:0045862	IDA
# BAK1	GO:0046902	IDA
# BAK1	GO:0051881	IDA
# BAK1	GO:0097202	IDA
# BARD1	GO:0046826	IDA
# BARD1	GO:0085020	IDA
# BAX	GO:0001783	IDA
# BAX	GO:0001836	IDA
# BAX	GO:0006915	IDA
# BAX	GO:0006919	IDA
# BAX	GO:0008053	IDA
# BAX	GO:0008635	IDA
# BAX	GO:0008637	IDA
# BAX	GO:0009636	IDA
# BAX	GO:0010248	IDA
# BAX	GO:0010917	IDA
# BAX	GO:0032091	IDA
# BAX	GO:0032461	IDA
# BAX	GO:0032976	IDA
# BAX	GO:0043065	IDA
# BAX	GO:0043496	IDA
# BAX	GO:0043525	IDA
# BAX	GO:0043653	IDA
# BAX	GO:0051259	IDA
# BAX	GO:0051260	IDA
# BAX	GO:0051881	IDA
# BAX	GO:0090200	IDA
# BAX	GO:0097190	IDA
# BAX	GO:0097191	IDA
# BAX	GO:0097193	IDA
# BAX	GO:1990117	IDA
# BCKDHA	GO:0009083	IDA
# CCND1	GO:0000082	IDA
# CCND1	GO:0000122	IDA
# CCND1	GO:0001934	IDA
# CCND1	GO:0006974	IDA
# CCND1	GO:0010971	IDA
# CCND1	GO:0031571	IDA
# CCND1	GO:0044321	IDA
# CCND1	GO:0045737	IDA
# CCND1	GO:0070141	IDA
# CCND1	GO:0071157	IDA
# BCL2	GO:0000209	IDA
# BCL2	GO:0006915	IDA
# BCL2	GO:0008625	IDA
# BCL2	GO:0009636	IDA
# BCL2	GO:0010039	IDA
# BCL2	GO:0022898	IDA
# BCL2	GO:0030307	IDA
# BCL2	GO:0032848	IDA
# BCL2	GO:0034097	IDA
# BCL2	GO:0035094	IDA
# BCL2	GO:0042100	IDA
# BCL2	GO:0042493	IDA
# BCL2	GO:0043066	IDA
# BCL2	GO:0043496	IDA
# BCL2	GO:0043497	IDA
# BCL2	GO:0043524	IDA
# BCL2	GO:0051607	IDA
# BCL2	GO:0051924	IDA
# BCL2	GO:0070059	IDA
# BCL2	GO:2001243	IDA
# BCL2L1	GO:0001836	IDA
# BCL2L1	GO:0019050	IDA
# BCL2L1	GO:0034097	IDA
# BCL2L1	GO:0043066	IDA
# BCL2L1	GO:0046902	IDA
# BCL2L1	GO:0051881	IDA
# BCL2L1	GO:1900118	IDA
# BCL2L1	GO:1902042	IDA
# BCL2L1	GO:1902230	IDA
# BCL2L1	GO:1902236	IDA
# BCL2L1	GO:1903077	IDA
# BCL2L1	GO:2001243	IDA
# BCL3	GO:0006351	IDA
# BCL3	GO:0006974	IDA
# BCL3	GO:0007249	IDA
# BCL3	GO:0009615	IDA
# BCL3	GO:0010225	IDA
# BCL3	GO:0042981	IDA
# BCL3	GO:0043066	IDA
# BCL3	GO:0045892	IDA
# BCL3	GO:0045893	IDA
# BCL6	GO:0000122	IDA
# BCL6	GO:0006974	IDA
# BCL6	GO:0030308	IDA
# BCL6	GO:0043065	IDA
# HCN2	GO:0071320	IDA
# HCN2	GO:0071321	IDA
# HCN2	GO:0071805	IDA
# HCN2	GO:0098719	IDA
# HCN2	GO:1990573	IDA
# BDKRB2	GO:0050482	IDA
# BDNF	GO:0007416	IDA
# BDNF	GO:0048668	IDA
# BDNF	GO:0048672	IDA
# BDNF	GO:0051965	IDA
# BDNF	GO:1900122	IDA
# CEACAM1	GO:0001915	IDA
# CEACAM1	GO:0030334	IDA
# CEACAM1	GO:0043318	IDA
# CEACAM1	GO:0044319	IDA
# CEACAM1	GO:0050860	IDA
# BHMT	GO:0006577	IDA
# BHMT	GO:0071267	IDA
# BICD1	GO:0033365	IDA
# BID	GO:0001836	IDA
# BID	GO:0032461	IDA
# BID	GO:0032464	IDA
# BID	GO:0090150	IDA
# BIK	GO:0032464	IDA
# BIK	GO:0090200	IDA
# PRDM1	GO:0000122	IDA
# BLK	GO:0018108	IDA
# BLK	GO:0050853	IDA
# BLM	GO:0000729	IDA
# BLM	GO:0006974	IDA
# BLM	GO:0007095	IDA
# BLM	GO:0010165	IDA
# BLM	GO:0031297	IDA
# BLM	GO:0032508	IDA
# BLM	GO:0044806	IDA
# BLM	GO:0045893	IDA
# BLM	GO:0051259	IDA
# BLM	GO:0051260	IDA
# BLM	GO:0061820	IDA
# BLM	GO:0071479	IDA
# BLM	GO:0072711	IDA
# BLM	GO:0072757	IDA
# BLVRA	GO:0055114	IDA
# BLVRB	GO:0042167	IDA
# BMI1	GO:0051443	IDA
# BMP1	GO:0006508	IDA
# BMP1	GO:0061036	IDA
# BMP2	GO:0000122	IDA
# BMP2	GO:0000187	IDA
# BMP2	GO:0001649	IDA
# BMP2	GO:0001837	IDA
# BMP2	GO:0001934	IDA
# BMP2	GO:0001938	IDA
# BMP2	GO:0002062	IDA
# BMP2	GO:0003130	IDA
# BMP2	GO:0003308	IDA
# BMP2	GO:0006355	IDA
# BMP2	GO:0006468	IDA
# BMP2	GO:0008285	IDA
# BMP2	GO:0010628	IDA
# BMP2	GO:0010629	IDA
# BMP2	GO:0010718	IDA
# BMP2	GO:0010862	IDA
# BMP2	GO:0010894	IDA
# BMP2	GO:0010922	IDA
# BMP2	GO:0021537	IDA
# BMP2	GO:0030501	IDA
# BMP2	GO:0030509	IDA
# BMP2	GO:0032092	IDA
# BMP2	GO:0032348	IDA
# BMP2	GO:0035051	IDA
# BMP2	GO:0035630	IDA
# BMP2	GO:0043065	IDA
# BMP2	GO:0043410	IDA
# BMP2	GO:0043569	IDA
# BMP2	GO:0045669	IDA
# BMP2	GO:0045778	IDA
# BMP2	GO:0045786	IDA
# BMP2	GO:0045892	IDA
# BMP2	GO:0045893	IDA
# BMP2	GO:0045944	IDA
# BMP2	GO:0048762	IDA
# BMP2	GO:0051042	IDA
# BMP2	GO:0060317	IDA
# BMP2	GO:0060389	IDA
# BMP2	GO:0060395	IDA
# BMP2	GO:0061036	IDA
# BMP2	GO:0070374	IDA
# BMP2	GO:0071773	IDA
# BMP2	GO:1900745	IDA
# BMP2	GO:1901522	IDA
# BMP2	GO:2000065	IDA
# BMP2	GO:2000726	IDA
# BMP4	GO:0000122	IDA
# BMP4	GO:0000186	IDA
# BMP4	GO:0001649	IDA
# BMP4	GO:0001657	IDA
# BMP4	GO:0001658	IDA
# BMP4	GO:0001934	IDA
# BMP4	GO:0001938	IDA
# BMP4	GO:0002043	IDA
# BMP4	GO:0002244	IDA
# BMP4	GO:0003323	IDA
# BMP4	GO:0003337	IDA
# BMP4	GO:0007182	IDA
# BMP4	GO:0008284	IDA
# BMP4	GO:0008285	IDA
# BMP4	GO:0009791	IDA
# BMP4	GO:0010453	IDA
# BMP4	GO:0010595	IDA
# BMP4	GO:0010628	IDA
# BMP4	GO:0010629	IDA
# BMP4	GO:0010862	IDA
# BMP4	GO:0010942	IDA
# BMP4	GO:0021537	IDA
# BMP4	GO:0030224	IDA
# BMP4	GO:0030225	IDA
# BMP4	GO:0030501	IDA
# BMP4	GO:0030509	IDA
# BMP4	GO:0032092	IDA
# BMP4	GO:0032967	IDA
# BMP4	GO:0034504	IDA
# BMP4	GO:0042306	IDA
# BMP4	GO:0042326	IDA
# BMP4	GO:0043065	IDA
# BMP4	GO:0043066	IDA
# BMP4	GO:0043407	IDA
# BMP4	GO:0045606	IDA
# BMP4	GO:0045662	IDA
# BMP4	GO:0045669	IDA
# BMP4	GO:0045778	IDA
# BMP4	GO:0045786	IDA
# BMP4	GO:0045839	IDA
# BMP4	GO:0045843	IDA
# BMP4	GO:0045892	IDA
# BMP4	GO:0045893	IDA
# BMP4	GO:0045944	IDA
# BMP4	GO:0048286	IDA
# BMP4	GO:0048392	IDA
# BMP4	GO:0048661	IDA
# BMP4	GO:0048754	IDA
# BMP4	GO:0050679	IDA
# BMP4	GO:0060391	IDA
# BMP4	GO:0060393	IDA
# BMP4	GO:0060395	IDA
# BMP4	GO:0060425	IDA
# BMP4	GO:0060433	IDA
# BMP4	GO:0060438	IDA
# BMP4	GO:0060441	IDA
# BMP4	GO:0060502	IDA
# BMP4	GO:0060503	IDA
# BMP4	GO:0060548	IDA
# BMP4	GO:0061036	IDA
# BMP4	GO:0061155	IDA
# BMP4	GO:0071893	IDA
# BMP4	GO:0072097	IDA
# BMP4	GO:0072101	IDA
# BMP4	GO:0072125	IDA
# BMP4	GO:0072200	IDA
# BMP4	GO:0090184	IDA
# BMP4	GO:0090191	IDA
# BMP4	GO:0090194	IDA
# BMP4	GO:1902894	IDA
# BMP4	GO:1903800	IDA
# BMP4	GO:2000005	IDA
# BMP4	GO:2000007	IDA
# BMP5	GO:0003323	IDA
# BMP5	GO:0008284	IDA
# BMP5	GO:0008285	IDA
# BMP5	GO:0010862	IDA
# BMP5	GO:0010894	IDA
# BMP5	GO:0032348	IDA
# BMP5	GO:0043569	IDA
# BMP5	GO:0045944	IDA
# BMP5	GO:0050679	IDA
# BMP5	GO:1900006	IDA
# BMP5	GO:2000065	IDA
# BMP6	GO:0003323	IDA
# BMP6	GO:0010862	IDA
# BMP6	GO:0030501	IDA
# BMP6	GO:0030509	IDA
# BMP6	GO:0032349	IDA
# BMP6	GO:0045669	IDA
# BMP6	GO:0045944	IDA
# BMP6	GO:0050679	IDA
# BMP6	GO:0060395	IDA
# BMP7	GO:0010628	IDA
# BMP7	GO:0010800	IDA
# BMP7	GO:0010862	IDA
# BMP7	GO:0030501	IDA
# BMP7	GO:0030509	IDA
# BMP7	GO:0034116	IDA
# BMP7	GO:0034504	IDA
# BMP7	GO:0042326	IDA
# BMP7	GO:0043407	IDA
# BMP7	GO:0045665	IDA
# BMP7	GO:0045669	IDA
# BMP7	GO:0045786	IDA
# BMP7	GO:0045839	IDA
# BMP7	GO:0045892	IDA
# BMP7	GO:0045893	IDA
# BMP7	GO:0048762	IDA
# BMP7	GO:0048812	IDA
# BMP7	GO:0060393	IDA
# BMP7	GO:0060395	IDA
# BMP7	GO:0060548	IDA
# BMP7	GO:0070487	IDA
# BMP7	GO:0072125	IDA
# BMP7	GO:1900006	IDA
# BMP7	GO:1900106	IDA
# BMPR1A	GO:0006468	IDA
# BMPR1A	GO:0010862	IDA
# BMPR1A	GO:0030509	IDA
# BMPR1A	GO:0060391	IDA
# BMPR1B	GO:0006468	IDA
# BMPR1B	GO:0030509	IDA
# BMPR2	GO:0007178	IDA
# BMPR2	GO:0010634	IDA
# BMPR2	GO:0030308	IDA
# BMPR2	GO:0030509	IDA
# BMX	GO:0007165	IDA
# BMX	GO:0046777	IDA
# POLR3D	GO:0032728	IDA
# POLR3D	GO:0045089	IDA
# BNIP3	GO:0008626	IDA
# BNIP3	GO:0010637	IDA
# BNIP3	GO:0043065	IDA
# BNIP3	GO:0043068	IDA
# BNIP3	GO:0043243	IDA
# BNIP3	GO:0043653	IDA
# BNIP3	GO:0045837	IDA
# BNIP3	GO:0046902	IDA
# BNIP3	GO:0051607	IDA
# BNIP3	GO:0072593	IDA
# BNIP3	GO:0090141	IDA
# BNIP3	GO:0090200	IDA
# BNIP3	GO:0097345	IDA
# BNIP3L	GO:0043065	IDA
# BNIP3L	GO:0043066	IDA
# BNIP3L	GO:0051607	IDA
# BOK	GO:0001836	IDA
# BOK	GO:0006915	IDA
# BOK	GO:0043065	IDA
# BOK	GO:1901382	IDA
# DST	GO:0009611	IDA
# FOXL2	GO:0045892	IDA
# BPI	GO:0032715	IDA
# BPI	GO:0032717	IDA
# BPI	GO:0032720	IDA
# BPI	GO:0043031	IDA
# BRCA1	GO:0000724	IDA
# BRCA1	GO:0006301	IDA
# BRCA1	GO:0006302	IDA
# BRCA1	GO:0008630	IDA
# BRCA1	GO:0016567	IDA
# BRCA1	GO:0031398	IDA
# BRCA1	GO:0035066	IDA
# BRCA1	GO:0043627	IDA
# BRCA1	GO:0045892	IDA
# BRCA1	GO:0045893	IDA
# BRCA1	GO:0045944	IDA
# BRCA1	GO:0051571	IDA
# BRCA1	GO:0051573	IDA
# BRCA1	GO:0051865	IDA
# BRCA1	GO:0070512	IDA
# BRCA1	GO:0071158	IDA
# BRCA1	GO:0071681	IDA
# BRCA1	GO:0085020	IDA
# BRCA1	GO:2000617	IDA
# BRCA1	GO:2000620	IDA
# BRAF	GO:0006468	IDA
# BRAF	GO:0010828	IDA
# BRAF	GO:0033138	IDA
# BRAF	GO:0043066	IDA
# BRAF	GO:0070374	IDA
# BRAF	GO:0071277	IDA
# BRAF	GO:0090150	IDA
# BRCA2	GO:0000281	IDA
# BRCA2	GO:0000724	IDA
# BRCA2	GO:0033600	IDA
# BRCA2	GO:0043966	IDA
# BRCA2	GO:0043967	IDA
# BRCA2	GO:0045893	IDA
# BRCA2	GO:0070200	IDA
# ZFP36L1	GO:0000165	IDA
# ZFP36L1	GO:0009611	IDA
# ZFP36L1	GO:0010468	IDA
# ZFP36L1	GO:0014065	IDA
# ZFP36L1	GO:0031440	IDA
# ZFP36L1	GO:0032869	IDA
# ZFP36L1	GO:0043488	IDA
# ZFP36L1	GO:0045647	IDA
# ZFP36L1	GO:0045657	IDA
# ZFP36L1	GO:0061158	IDA
# ZFP36L1	GO:0070371	IDA
# ZFP36L1	GO:0071320	IDA
# ZFP36L1	GO:0071356	IDA
# ZFP36L1	GO:0071364	IDA
# ZFP36L1	GO:0071375	IDA
# ZFP36L1	GO:0071385	IDA
# ZFP36L1	GO:0071560	IDA
# ZFP36L2	GO:0009611	IDA
# ZFP36L2	GO:0044344	IDA
# ZFP36L2	GO:0070371	IDA
# ZFP36L2	GO:0071356	IDA
# ZFP36L2	GO:0071364	IDA
# ZFP36L2	GO:0071385	IDA
# ZFP36L2	GO:0071560	IDA
# ZFP36L2	GO:0097011	IDA
# BST1	GO:0001952	IDA
# BST1	GO:0008284	IDA
# BST1	GO:0032956	IDA
# BST1	GO:0050727	IDA
# BST1	GO:0050730	IDA
# BST1	GO:0090022	IDA
# BST2	GO:0002737	IDA
# BST2	GO:0009615	IDA
# BST2	GO:0030308	IDA
# BST2	GO:0030336	IDA
# BST2	GO:0045071	IDA
# BST2	GO:0045087	IDA
# BST2	GO:0051607	IDA
# BST2	GO:1901253	IDA
# KLF9	GO:0071387	IDA
# KLF9	GO:0097067	IDA
# KLF5	GO:0045944	IDA
# KLF5	GO:0099156	IDA
# KLF5	GO:1902895	IDA
# BTG1	GO:0008285	IDA
# BTG1	GO:0045663	IDA
# BTK	GO:0018108	IDA
# BUB1	GO:0007063	IDA
# C1QBP	GO:0000122	IDA
# C1QBP	GO:0030449	IDA
# C1QBP	GO:0032689	IDA
# C1QBP	GO:0032695	IDA
# C1QBP	GO:0039534	IDA
# C1QBP	GO:0039536	IDA
# C1QBP	GO:0048025	IDA
# C1QBP	GO:0090023	IDA
# SERPING1	GO:0001869	IDA
# C1QC	GO:0030853	IDA
# C1QC	GO:0045650	IDA
# C1R	GO:0031638	IDA
# C3	GO:0001934	IDA
# C3	GO:0010575	IDA
# C3	GO:0010828	IDA
# C3	GO:0010866	IDA
# C3	GO:0010884	IDA
# C3	GO:0045745	IDA
# C3AR1	GO:0002430	IDA
# C4B	GO:0032490	IDA
# C4BPA	GO:0045732	IDA
# C4BPA	GO:0045959	IDA
# C4BPB	GO:0045732	IDA
# C4BPB	GO:0045959	IDA
# C5	GO:0010575	IDA
# C5	GO:0010760	IDA
# C5	GO:0090197	IDA
# C5AR1	GO:0038178	IDA
# C5AR1	GO:0042789	IDA
# C5AR1	GO:0050679	IDA
# C5AR1	GO:0070374	IDA
# C8A	GO:0006956	IDA
# C9	GO:0001906	IDA
# C9	GO:0051260	IDA
# VPS51	GO:0042147	IDA
# DAGLA	GO:0019369	IDA
# DAGLA	GO:0042136	IDA
# DAGLA	GO:0046340	IDA
# LDLRAD4	GO:0010991	IDA
# PTTG1IP	GO:0006606	IDA
# PTTG1IP	GO:0031398	IDA
# PTTG1IP	GO:1903364	IDA
# CFAP410	GO:0042769	IDA
# CA2	GO:0038166	IDA
# CA2	GO:0044070	IDA
# CA6	GO:0001580	IDA
# CACNA1A	GO:0007204	IDA
# CACNA1A	GO:0008219	IDA
# CACNA1A	GO:0050804	IDA
# CACNA1A	GO:0070588	IDA
# CACNA1A	GO:1904645	IDA
# CACNA1A	GO:1904646	IDA
# CACNA1B	GO:0050804	IDA
# CACNA1B	GO:1904645	IDA
# CACNA1C	GO:0007204	IDA
# CACNA1C	GO:0061577	IDA
# CACNA1C	GO:0070588	IDA
# CACNA1D	GO:0006816	IDA
# CACNA1D	GO:0051928	IDA
# CACNA1D	GO:0070509	IDA
# CACNA1S	GO:0006816	IDA
# DDR1	GO:0038063	IDA
# DDR1	GO:0038083	IDA
# DDR1	GO:0046777	IDA
# CACNA2D1	GO:0006816	IDA
# CACNA2D1	GO:0051924	IDA
# CACNB2	GO:0051928	IDA
# CACNB2	GO:0070509	IDA
# CACNB3	GO:0006816	IDA
# CAD	GO:0006207	IDA
# CALCA	GO:0002548	IDA
# CALCA	GO:0007189	IDA
# CALCA	GO:0007204	IDA
# CALCA	GO:0007566	IDA
# CALCA	GO:0032147	IDA
# CALCA	GO:0045779	IDA
# CALCA	GO:0045892	IDA
# CALCA	GO:0051482	IDA
# CALCR	GO:0007189	IDA
# CALCR	GO:0051384	IDA
# CALCR	GO:0097647	IDA
# CALM1	GO:0010880	IDA
# CALM1	GO:0032516	IDA
# CALM1	GO:0035307	IDA
# CALM1	GO:0051343	IDA
# CALM1	GO:0051592	IDA
# CALM1	GO:0060314	IDA
# CALM1	GO:0060315	IDA
# CALM1	GO:0060316	IDA
# CALM1	GO:0075206	IDA
# CALM2	GO:0010880	IDA
# CALM2	GO:0032516	IDA
# CALM2	GO:0035307	IDA
# CALM2	GO:0051343	IDA
# CALM2	GO:0051592	IDA
# CALM2	GO:0060315	IDA
# CALM2	GO:0060316	IDA
# CALM2	GO:0075206	IDA
# CALM3	GO:0010880	IDA
# CALM3	GO:0032516	IDA
# CALM3	GO:0035307	IDA
# CALM3	GO:0051343	IDA
# CALM3	GO:0051592	IDA
# CALM3	GO:0060316	IDA
# CALM3	GO:0075206	IDA
# CALR	GO:0000122	IDA
# CALR	GO:0006611	IDA
# CALR	GO:0017148	IDA
# CALR	GO:0033144	IDA
# CALR	GO:0034504	IDA
# CALR	GO:0045665	IDA
# CALR	GO:0045892	IDA
# CALR	GO:0048387	IDA
# CAMK4	GO:0045893	IDA
# CAMK2A	GO:0006468	IDA
# CAMK2A	GO:0038166	IDA
# CAMK2B	GO:0046777	IDA
# CAMK2D	GO:0003254	IDA
# CAMK2D	GO:0006468	IDA
# CAMK2D	GO:0018105	IDA
# CAMK2D	GO:0018107	IDA
# CAMK2D	GO:0046777	IDA
# CAMK2D	GO:0051259	IDA
# CAMK2D	GO:1901897	IDA
# CAMK2D	GO:1902306	IDA
# CAMK2D	GO:2000650	IDA
# CAMK2G	GO:0051259	IDA
# CAMP	GO:0002227	IDA
# CAMP	GO:0019731	IDA
# CAMP	GO:0044140	IDA
# CAMP	GO:0050830	IDA
# CAMP	GO:0051873	IDA
# CAMP	GO:0061844	IDA
# CAPN1	GO:0006508	IDA
# CAPN1	GO:0050790	IDA
# CAPN1	GO:0097264	IDA
# CAPN2	GO:0051603	IDA
# CAPN3	GO:0006508	IDA
# CAPN3	GO:0033234	IDA
# CAPN3	GO:0050790	IDA
# CAPN3	GO:0097264	IDA
# CAPN3	GO:1990092	IDA
# CAST	GO:2000675	IDA
# CARS	GO:0006423	IDA
# CASP1	GO:0006508	IDA
# CASP1	GO:0016540	IDA
# CASP1	GO:0050718	IDA
# CASP1	GO:0071310	IDA
# CASP2	GO:0016485	IDA
# CASP2	GO:0043065	IDA
# CASP3	GO:0006508	IDA
# CASP3	GO:0030218	IDA
# CASP3	GO:0031647	IDA
# CASP3	GO:0048011	IDA
# CASP3	GO:0097194	IDA
# CASP3	GO:1902004	IDA
# CASP4	GO:1903265	IDA
# CASP6	GO:0006508	IDA
# CASP7	GO:0006508	IDA
# CASP7	GO:0006915	IDA
# CASP8	GO:0006508	IDA
# CASP8	GO:0036462	IDA
# CASP8	GO:0045862	IDA
# CASP8	GO:0097191	IDA
# CASP8	GO:0097202	IDA
# CASP9	GO:0006974	IDA
# CASP9	GO:0034644	IDA
# CASP9	GO:0042770	IDA
# CASQ1	GO:0051258	IDA
# CASQ2	GO:0051208	IDA
# CASQ2	GO:0051258	IDA
# CASQ2	GO:0060315	IDA
# CASR	GO:0005513	IDA
# CASR	GO:0006874	IDA
# CASR	GO:0007186	IDA
# CASR	GO:0070509	IDA
# CAT	GO:0042744	IDA
# CAT	GO:0051262	IDA
# CAT	GO:0051289	IDA
# CAV1	GO:0009617	IDA
# CAV1	GO:0030512	IDA
# CAV1	GO:0031295	IDA
# CAV1	GO:0031623	IDA
# CAV1	GO:0032091	IDA
# CAV1	GO:0032570	IDA
# CAV1	GO:0033137	IDA
# CAV1	GO:0033138	IDA
# CAV1	GO:0043627	IDA
# CAV1	GO:0051480	IDA
# CAV1	GO:0072584	IDA
# CAV1	GO:1900027	IDA
# CAV1	GO:2000535	IDA
# CAV2	GO:0006906	IDA
# CAV2	GO:0008286	IDA
# CAV2	GO:0016050	IDA
# CAV2	GO:0043410	IDA
# CAV2	GO:0043547	IDA
# CAV2	GO:0048278	IDA
# CAV2	GO:0070836	IDA
# CAV3	GO:0042391	IDA
# CAV3	GO:0051926	IDA
# CAV3	GO:0060373	IDA
# CAV3	GO:0070836	IDA
# CAV3	GO:0090279	IDA
# CAV3	GO:1901019	IDA
# CAV3	GO:2000649	IDA
# RUNX2	GO:0045892	IDA
# RUNX2	GO:0045893	IDA
# RUNX1	GO:0030097	IDA
# RUNX1	GO:0045893	IDA
# RUNX1	GO:0045944	IDA
# RUNX1T1	GO:0045892	IDA
# CBFA2T3	GO:0001666	IDA
# CBFA2T3	GO:0008285	IDA
# CBFA2T3	GO:0030851	IDA
# CBFA2T3	GO:0045820	IDA
# CBFA2T3	GO:0045892	IDA
# CBFA2T3	GO:1903715	IDA
# RUNX3	GO:0006468	IDA
# RUNX3	GO:0045893	IDA
# RUNX3	GO:0071559	IDA
# CBR1	GO:0017144	IDA
# CBR1	GO:0042373	IDA
# CBR1	GO:0055114	IDA
# CBS	GO:0006563	IDA
# CBS	GO:0006565	IDA
# CBS	GO:0019344	IDA
# CBS	GO:0019448	IDA
# CBS	GO:0043418	IDA
# CBS	GO:0050667	IDA
# CBS	GO:0070814	IDA
# KYAT1	GO:0070189	IDA
# CCKAR	GO:0038188	IDA
# CCKBR	GO:0007200	IDA
# CCKBR	GO:0007204	IDA
# CCKBR	GO:0008284	IDA
# CCKBR	GO:0038188	IDA
# CCNA2	GO:0000086	IDA
# CCNA2	GO:0016572	IDA
# CCNA2	GO:0044843	IDA
# CCNB1	GO:0010971	IDA
# CCNB1	GO:1905448	IDA
# CCND2	GO:0001934	IDA
# CCND2	GO:0045737	IDA
# CCND3	GO:0001934	IDA
# CCND3	GO:0045737	IDA
# CCNF	GO:0010826	IDA
# CCNF	GO:0016567	IDA
# CCNF	GO:0031146	IDA
# CCNH	GO:0006366	IDA
# CCNH	GO:0045944	IDA
# CCNT1	GO:0045944	IDA
# CCNT2	GO:0019085	IDA
# CCNT2	GO:0019086	IDA
# CCNT2	GO:0045944	IDA
# CD1C	GO:0002286	IDA
# CD1D	GO:0042102	IDA
# CD1D	GO:0048006	IDA
# CD2	GO:0032760	IDA
# CD2	GO:0034113	IDA
# CD2	GO:1902715	IDA
# CD3D	GO:0030217	IDA
# CD3D	GO:0045944	IDA
# CD4	GO:0001934	IDA
# CD4	GO:0006948	IDA
# CD4	GO:0030217	IDA
# CD4	GO:0032507	IDA
# CD4	GO:0033674	IDA
# CD4	GO:0035723	IDA
# CD4	GO:0043123	IDA
# CD4	GO:0043410	IDA
# CD4	GO:0045058	IDA
# CD4	GO:0045657	IDA
# CD4	GO:0045860	IDA
# CD4	GO:0045893	IDA
# CD4	GO:0046598	IDA
# CD4	GO:0050863	IDA
# CD4	GO:0051924	IDA
# CD4	GO:0070374	IDA
# CD4	GO:0097011	IDA
# CD6	GO:0002438	IDA
# CD6	GO:0031663	IDA
# CD6	GO:0032496	IDA
# CD6	GO:1900017	IDA
# CD9	GO:0007155	IDA
# CD9	GO:0007342	IDA
# CD9	GO:0051271	IDA
# CD9	GO:0090331	IDA
# CD14	GO:0032760	IDA
# CD14	GO:0071219	IDA
# CD14	GO:0071222	IDA
# CD14	GO:0071223	IDA
# CD14	GO:0071726	IDA
# CD14	GO:0071727	IDA
# CD14	GO:1901224	IDA
# CD19	GO:0002322	IDA
# CD19	GO:0050851	IDA
# CD19	GO:0050864	IDA
# CD19	GO:0051281	IDA
# MS4A1	GO:0030183	IDA
# MS4A1	GO:0042113	IDA
# MS4A1	GO:0050853	IDA
# MS4A1	GO:0051262	IDA
# MS4A1	GO:1902656	IDA
# CD22	GO:0030100	IDA
# CD22	GO:0042113	IDA
# CD22	GO:0050859	IDA
# CD27	GO:0043066	IDA
# CD27	GO:0097191	IDA
# CD28	GO:0032733	IDA
# CD28	GO:0032753	IDA
# CD28	GO:0042102	IDA
# CD28	GO:0045066	IDA
# CD28	GO:0045086	IDA
# CD28	GO:0045840	IDA
# CD80	GO:0050731	IDA
# TNFRSF8	GO:0042535	IDA
# TNFRSF8	GO:0043065	IDA
# TNFRSF8	GO:0045556	IDA
# CD33	GO:0002765	IDA
# CD34	GO:0001894	IDA
# CD34	GO:0001935	IDA
# CD34	GO:0008217	IDA
# CD34	GO:0030195	IDA
# CD34	GO:0032720	IDA
# CD34	GO:0032733	IDA
# CD34	GO:0038001	IDA
# CD34	GO:0042482	IDA
# CD34	GO:0045019	IDA
# CD34	GO:0045766	IDA
# CD34	GO:0071636	IDA
# CD34	GO:0071657	IDA
# CD34	GO:0071971	IDA
# CD34	GO:0098609	IDA
# CD34	GO:1900035	IDA
# CD34	GO:1900038	IDA
# CD34	GO:1900168	IDA
# CD34	GO:1901215	IDA
# CD34	GO:2001214	IDA
# CD36	GO:0001954	IDA
# CD36	GO:0007263	IDA
# CD36	GO:0019934	IDA
# CD36	GO:0044539	IDA
# CD36	GO:0071726	IDA
# SCARB1	GO:0010886	IDA
# SCARB1	GO:0015920	IDA
# SCARB1	GO:0032497	IDA
# SCARB1	GO:0034384	IDA
# SCARB1	GO:0043654	IDA
# SCARB1	GO:0051000	IDA
# CD40	GO:2000353	IDA
# CD40LG	GO:0006954	IDA
# CD40LG	GO:0007257	IDA
# CD40LG	GO:0030168	IDA
# CD40LG	GO:0032733	IDA
# CD40LG	GO:0032735	IDA
# CD40LG	GO:0032753	IDA
# CD40LG	GO:0042100	IDA
# CD40LG	GO:0042102	IDA
# CD40LG	GO:0043066	IDA
# CD40LG	GO:0051092	IDA
# CD40LG	GO:2000353	IDA
# CD44	GO:0007155	IDA
# CD44	GO:0016477	IDA
# CD44	GO:0030214	IDA
# CD44	GO:0033138	IDA
# CD44	GO:0042110	IDA
# CD44	GO:0043518	IDA
# CD44	GO:0044344	IDA
# CD44	GO:0050731	IDA
# CD44	GO:0070374	IDA
# CD44	GO:1902166	IDA
# CD47	GO:0008284	IDA
# CD47	GO:0022409	IDA
# CD47	GO:0050870	IDA
# CD58	GO:0034113	IDA
# CD58	GO:0071346	IDA
# CD58	GO:0071356	IDA
# CD59	GO:0030449	IDA
# CD59	GO:1903659	IDA
# CD63	GO:0034613	IDA
# CD63	GO:1901379	IDA
# CD70	GO:0097191	IDA
# CD74	GO:0001516	IDA
# CD74	GO:0001934	IDA
# CD74	GO:0002792	IDA
# CD74	GO:0007165	IDA
# CD74	GO:0008283	IDA
# CD74	GO:0033674	IDA
# CD74	GO:0043066	IDA
# CD74	GO:0043123	IDA
# CD74	GO:0043410	IDA
# CD74	GO:0043518	IDA
# CD74	GO:0045657	IDA
# CD74	GO:0045893	IDA
# CD74	GO:0046598	IDA
# CD74	GO:0050731	IDA
# CD74	GO:0051290	IDA
# CD74	GO:0070374	IDA
# CD81	GO:0000187	IDA
# CD81	GO:0008104	IDA
# CD81	GO:0008284	IDA
# CD81	GO:0030890	IDA
# CD81	GO:0034238	IDA
# CD81	GO:0035783	IDA
# CD81	GO:0043128	IDA
# CD81	GO:0050731	IDA
# CD81	GO:0072659	IDA
# CD81	GO:1903911	IDA
# CD81	GO:2000553	IDA
# CD81	GO:2000563	IDA
# CD81	GO:2001190	IDA
# CD151	GO:0030335	IDA
# CD151	GO:0044319	IDA
# CD151	GO:0045807	IDA
# CDA	GO:0009972	IDA
# CDA	GO:0030308	IDA
# CDA	GO:0045980	IDA
# CDA	GO:0051289	IDA
# CDK1	GO:0006468	IDA
# CDK1	GO:0018105	IDA
# CDK1	GO:0018107	IDA
# CDK1	GO:0034501	IDA
# CDK1	GO:0043066	IDA
# CDK11B	GO:0006468	IDA
# CDK11B	GO:0050684	IDA
# CDC5L	GO:0000398	IDA
# CDC5L	GO:0045944	IDA
# SEPTIN7	GO:0030336	IDA
# SEPTIN7	GO:0043065	IDA
# SEPTIN7	GO:0051291	IDA
# SEPTIN7	GO:2000134	IDA
# CDC6	GO:0051984	IDA
# CDC20	GO:0031145	IDA
# CDC20	GO:1904668	IDA
# CDC25A	GO:0009314	IDA
# CDC25A	GO:0034644	IDA
# CDC25B	GO:0006468	IDA
# CDC27	GO:0070979	IDA
# CDC34	GO:0000209	IDA
# CDC34	GO:0016567	IDA
# CDC34	GO:0043161	IDA
# CDC34	GO:0043951	IDA
# CDC34	GO:0070936	IDA
# CDC42	GO:0030036	IDA
# CDC42	GO:0031274	IDA
# CDC42	GO:0051489	IDA
# CDC42	GO:1900026	IDA
# CDH1	GO:0042307	IDA
# CDH1	GO:0045893	IDA
# CDH1	GO:0071285	IDA
# CDH1	GO:0071681	IDA
# CDH1	GO:0072659	IDA
# CDH1	GO:0098609	IDA
# CDH5	GO:0007179	IDA
# CDH13	GO:0002040	IDA
# CDH13	GO:0007156	IDA
# CDH13	GO:0007162	IDA
# CDH13	GO:0008285	IDA
# CDH13	GO:0016339	IDA
# CDH13	GO:0030032	IDA
# CDH13	GO:0030335	IDA
# CDH13	GO:0043542	IDA
# CDH13	GO:0043616	IDA
# CDH13	GO:0050850	IDA
# CDH13	GO:0050927	IDA
# CDH13	GO:0055096	IDA
# CDK2	GO:0006468	IDA
# CDK2	GO:0008284	IDA
# CDK2	GO:0016572	IDA
# CDK2	GO:0018105	IDA
# CDK2	GO:0060968	IDA
# CDK3	GO:0006974	IDA
# CDK4	GO:0006468	IDA
# CDK4	GO:0010971	IDA
# CDK4	GO:0071157	IDA
# CDK5	GO:0016310	IDA
# CDK5	GO:0018105	IDA
# CDK5	GO:0048709	IDA
# CDK5	GO:1901215	IDA
# CDK6	GO:0001954	IDA
# CDK6	GO:0003323	IDA
# CDK6	GO:0006468	IDA
# CDK6	GO:0010468	IDA
# CDK6	GO:0045638	IDA
# CDK6	GO:0045656	IDA
# CDK6	GO:0045668	IDA
# CDK6	GO:0045786	IDA
# CDK6	GO:2000773	IDA
# CDK7	GO:0006366	IDA
# CDK7	GO:0045944	IDA
# CDK9	GO:0006282	IDA
# CDK9	GO:0006468	IDA
# CDK9	GO:0031056	IDA
# CDK9	GO:0031297	IDA
# CDK9	GO:0071157	IDA
# CDK9	GO:0071345	IDA
# CDK9	GO:1903839	IDA
# CDKN1A	GO:0000082	IDA
# CDKN1A	GO:0006977	IDA
# CDKN1A	GO:0007050	IDA
# CDKN1A	GO:0008285	IDA
# CDKN1A	GO:0030308	IDA
# CDKN1A	GO:0042326	IDA
# CDKN1A	GO:0045860	IDA
# CDKN1B	GO:0000082	IDA
# CDKN1B	GO:0008285	IDA
# CDKN1B	GO:0010942	IDA
# CDKN1B	GO:0030308	IDA
# CDKN1B	GO:0033673	IDA
# CDKN1B	GO:0042326	IDA
# CDKN1B	GO:0045732	IDA
# CDKN1B	GO:0045736	IDA
# CDKN1B	GO:0045892	IDA
# CDKN1B	GO:0045930	IDA
# CDKN1B	GO:0048102	IDA
# CDKN1B	GO:0071285	IDA
# CDKN1B	GO:0071850	IDA
# CDKN1C	GO:0033673	IDA
# CDKN1C	GO:0042326	IDA
# CDKN1C	GO:0045892	IDA
# CDKN2A	GO:0000082	IDA
# CDKN2A	GO:0007050	IDA
# CDKN2A	GO:0008285	IDA
# CDKN2A	GO:0030308	IDA
# CDKN2A	GO:0032088	IDA
# CDKN2A	GO:0042326	IDA
# CDKN2A	GO:0045736	IDA
# CDKN2B	GO:0000079	IDA
# CDKN2B	GO:0042326	IDA
# CDKN2C	GO:0000079	IDA
# CDKN2C	GO:0000082	IDA
# CDKN2C	GO:0007050	IDA
# CDKN2C	GO:0008285	IDA
# CDKN2C	GO:0030308	IDA
# CDKN2C	GO:0042326	IDA
# CDKN2D	GO:0000079	IDA
# CDKN2D	GO:0000082	IDA
# CDKN2D	GO:0007050	IDA
# CDKN2D	GO:0008285	IDA
# CDKN2D	GO:0030308	IDA
# CDKN2D	GO:0042326	IDA
# CDKN3	GO:0007050	IDA
# CDS1	GO:0006661	IDA
# CDS1	GO:0016024	IDA
# CDSN	GO:0098609	IDA
# CD52	GO:0007204	IDA
# CDX1	GO:0045944	IDA
# CDX2	GO:0000122	IDA
# CDX4	GO:0045944	IDA
# CEACAM5	GO:0010832	IDA
# CEACAM5	GO:0034109	IDA
# CEACAM5	GO:0043066	IDA
# CEACAM5	GO:2000811	IDA
# CEBPA	GO:0006351	IDA
# CEBPA	GO:0008285	IDA
# CEBPA	GO:0045944	IDA
# CEBPA	GO:0045945	IDA
# CEBPA	GO:0070102	IDA
# CEBPB	GO:0006355	IDA
# CEBPB	GO:0034976	IDA
# CEBPB	GO:0045893	IDA
# CEBPB	GO:0045944	IDA
# CEBPB	GO:0070169	IDA
# CEBPB	GO:1990440	IDA
# CEBPB	GO:2000120	IDA
# CEBPE	GO:0045944	IDA
# CEBPG	GO:0006357	IDA
# CEBPG	GO:0045944	IDA
# CEL	GO:0006707	IDA
# CEL	GO:0030157	IDA
# CENPA	GO:0051382	IDA
# CENPA	GO:0071459	IDA
# CENPE	GO:0007079	IDA
# CENPE	GO:0051382	IDA
# CENPE	GO:0099606	IDA
# CENPF	GO:0015031	IDA
# CENPF	GO:0045892	IDA
# CENPF	GO:0051310	IDA
# CES1	GO:0006695	IDA
# CES1	GO:0030855	IDA
# CES1	GO:0051791	IDA
# CETN2	GO:0006289	IDA
# CETP	GO:0006641	IDA
# CETP	GO:0006869	IDA
# CETP	GO:0008203	IDA
# CETP	GO:0015914	IDA
# CETP	GO:0030301	IDA
# CETP	GO:0034197	IDA
# CETP	GO:0034372	IDA
# CETP	GO:0034374	IDA
# CETP	GO:0034375	IDA
# CETP	GO:0046470	IDA
# CETP	GO:0055088	IDA
# CETP	GO:0055091	IDA
# CETP	GO:0070328	IDA
# CFL1	GO:0030042	IDA
# CFL2	GO:0030042	IDA
# CTSC	GO:0006508	IDA
# CFTR	GO:0015701	IDA
# CFTR	GO:0034976	IDA
# CFTR	GO:1902476	IDA
# CFTR	GO:1902943	IDA
# CFTR	GO:1904322	IDA
# CGA	GO:0007186	IDA
# CGA	GO:0010469	IDA
# CGA	GO:0010893	IDA
# CEACAM4	GO:0006909	IDA
# RCC1	GO:0007052	IDA
# RCC1	GO:0007088	IDA
# RCC1	GO:0051290	IDA
# CHD3	GO:0007051	IDA
# CHD3	GO:0007098	IDA
# AKR1C4	GO:0071395	IDA
# CHEK1	GO:0000077	IDA
# CHEK1	GO:0006915	IDA
# CHEK1	GO:0006975	IDA
# CHEK1	GO:0010569	IDA
# CHEK1	GO:0018107	IDA
# CHEK1	GO:0045787	IDA
# CHEK1	GO:0045839	IDA
# CHEK1	GO:0046602	IDA
# FOXN3	GO:0045892	IDA
# CHGA	GO:0002551	IDA
# CHGA	GO:0032762	IDA
# CHGA	GO:0033604	IDA
# CHGA	GO:0043303	IDA
# CHGA	GO:0045576	IDA
# CHGA	GO:0050829	IDA
# CHGA	GO:0050830	IDA
# CHIT1	GO:0006032	IDA
# CHKA	GO:0006646	IDA
# CHKA	GO:0006656	IDA
# CHKB	GO:0006646	IDA
# CHM	GO:0018344	IDA
# CHML	GO:0018344	IDA
# CHRM2	GO:0007213	IDA
# CHRNA2	GO:0007165	IDA
# CHRNA3	GO:0007165	IDA
# CHRNA4	GO:0001666	IDA
# CHRNA4	GO:0007165	IDA
# CHRNA4	GO:0035094	IDA
# CHRNA7	GO:0000187	IDA
# CHRNA7	GO:0001666	IDA
# CHRNA7	GO:0006816	IDA
# CHRNA7	GO:0007165	IDA
# CHRNA7	GO:0032720	IDA
# CHRNA7	GO:0034220	IDA
# CHRNA7	GO:0035094	IDA
# CHRNA7	GO:1905144	IDA
# CHRNB2	GO:0001666	IDA
# CHRNB2	GO:0007165	IDA
# CHRNB2	GO:0035094	IDA
# CHRNB4	GO:0007165	IDA
# CHUK	GO:0006468	IDA
# CHUK	GO:0045944	IDA
# CHUK	GO:0071356	IDA
# CIRBP	GO:0009411	IDA
# CIRBP	GO:0045727	IDA
# CIRBP	GO:0048255	IDA
# ERCC8	GO:0000209	IDA
# ERCC8	GO:0006283	IDA
# ERCC8	GO:0006974	IDA
# ERCC8	GO:0006979	IDA
# ERCC8	GO:0009411	IDA
# ERCC8	GO:0043161	IDA
# ERCC8	GO:0051865	IDA
# CLC	GO:0070231	IDA
# CLCN3	GO:1902476	IDA
# CLCN4	GO:0006821	IDA
# CLU	GO:0000902	IDA
# CLU	GO:0001774	IDA
# CLU	GO:0017038	IDA
# CLU	GO:0032463	IDA
# CLU	GO:0032464	IDA
# CLU	GO:0032760	IDA
# CLU	GO:0045429	IDA
# CLU	GO:0050821	IDA
# CLU	GO:0051131	IDA
# CLU	GO:0051788	IDA
# CLU	GO:0061077	IDA
# CLU	GO:0061518	IDA
# CLU	GO:1900221	IDA
# CLU	GO:1901214	IDA
# CLU	GO:1901216	IDA
# CLU	GO:1902430	IDA
# CLU	GO:1905907	IDA
# CLIC1	GO:0006821	IDA
# CLIC2	GO:0010880	IDA
# CLIC2	GO:0051099	IDA
# CLIC2	GO:0060315	IDA
# CLK2	GO:0006468	IDA
# CLK2	GO:0043484	IDA
# CLK3	GO:0006468	IDA
# CLK3	GO:0043484	IDA
# CLN3	GO:0006672	IDA
# CLN3	GO:0015809	IDA
# CLN3	GO:0035752	IDA
# CLN3	GO:0042987	IDA
# CLN5	GO:0006465	IDA
# CLN5	GO:0070085	IDA
# CLNS1A	GO:0000387	IDA
# CLTC	GO:1900126	IDA
# CMA1	GO:0022617	IDA
# CMA1	GO:0034769	IDA
# CMA1	GO:0050720	IDA
# CCR1	GO:0006816	IDA
# CCR1	GO:0006874	IDA
# CCR1	GO:0006887	IDA
# CCR1	GO:0006955	IDA
# CCR1	GO:0007204	IDA
# CCR1	GO:0007267	IDA
# CCR1	GO:0051928	IDA
# CCR1	GO:0070098	IDA
# CCR1	GO:0090026	IDA
# CCR5	GO:0006816	IDA
# CCR5	GO:0007267	IDA
# CCR5	GO:0014808	IDA
# CCR5	GO:0019722	IDA
# CCR6	GO:0006935	IDA
# CCR6	GO:0060326	IDA
# CCR6	GO:0060474	IDA
# CCR7	GO:0002408	IDA
# CCR7	GO:0071345	IDA
# CCR7	GO:0090023	IDA
# CMKLR1	GO:0006935	IDA
# CMKLR1	GO:0007186	IDA
# CMKLR1	GO:0032088	IDA
# CMKLR1	GO:0050848	IDA
# CNGB1	GO:0006812	IDA
# PLK3	GO:0000122	IDA
# PLK3	GO:0000302	IDA
# PLK3	GO:0006970	IDA
# PLK3	GO:0006974	IDA
# PLK3	GO:0009314	IDA
# PLK3	GO:0043066	IDA
# PLK3	GO:0051302	IDA
# PLK3	GO:0090166	IDA
# PLK3	GO:1904716	IDA
# PLK3	GO:2000777	IDA
# CNN2	GO:0032970	IDA
# CNN2	GO:0071260	IDA
# CNR1	GO:0007188	IDA
# CNR1	GO:0038171	IDA
# CNTF	GO:0010628	IDA
# CNTF	GO:0042531	IDA
# CNTF	GO:0043524	IDA
# CNTF	GO:0070120	IDA
# CNTFR	GO:0070120	IDA
# COL1A1	GO:0010718	IDA
# COL1A1	GO:0030335	IDA
# COL1A1	GO:0034504	IDA
# COL1A1	GO:0045893	IDA
# COL1A1	GO:0090263	IDA
# COL1A2	GO:0007179	IDA
# COL1A2	GO:0007266	IDA
# COL3A1	GO:0007160	IDA
# COL3A1	GO:0007179	IDA
# COL3A1	GO:0009314	IDA
# COL3A1	GO:0018149	IDA
# COL3A1	GO:0034097	IDA
# COL3A1	GO:0042060	IDA
# COL4A2	GO:0016525	IDA
# COL4A3	GO:0006919	IDA
# COL4A3	GO:0008283	IDA
# COL4A3	GO:0016525	IDA
# COL4A3	GO:0072577	IDA
# COL5A1	GO:1903225	IDA
# COL5A2	GO:1903225	IDA
# COL11A2	GO:0030199	IDA
# COL16A1	GO:0007155	IDA
# COL16A1	GO:0033622	IDA
# COL16A1	GO:0033627	IDA
# COL16A1	GO:0051894	IDA
# COL17A1	GO:0031581	IDA
# COMP	GO:0043066	IDA
# COMP	GO:0060173	IDA
# COMT	GO:0042424	IDA
# COPA	GO:0030157	IDA
# KLF6	GO:0045944	IDA
# CORT	GO:0007193	IDA
# COX11	GO:0055065	IDA
# CPE	GO:0016055	IDA
# CPE	GO:0072657	IDA
# CPS1	GO:0032496	IDA
# CPS1	GO:0050667	IDA
# CPT1A	GO:0001676	IDA
# CPT1A	GO:0009437	IDA
# CR1	GO:0045957	IDA
# CR1	GO:0045959	IDA
# CR1	GO:1900004	IDA
# CR1	GO:1900005	IDA
# CR1L	GO:0030449	IDA
# CR1L	GO:1903659	IDA
# CR2	GO:0030183	IDA
# CR2	GO:0042100	IDA
# CRAT	GO:0019254	IDA
# CREB1	GO:0006468	IDA
# CREB1	GO:0010033	IDA
# CREB1	GO:0010944	IDA
# CREB1	GO:0045944	IDA
# ATF2	GO:0006357	IDA
# ATF2	GO:0006970	IDA
# ATF2	GO:0006974	IDA
# ATF2	GO:0045944	IDA
# ATF2	GO:0110024	IDA
# CREBBP	GO:0000122	IDA
# CREBBP	GO:0006355	IDA
# CREBBP	GO:0006473	IDA
# CREBBP	GO:0016573	IDA
# CREBBP	GO:0018076	IDA
# CREBBP	GO:0034644	IDA
# CREBBP	GO:0045893	IDA
# ATF6B	GO:0045944	IDA
# ATF6B	GO:1903892	IDA
# ATF6B	GO:1990440	IDA
# CREM	GO:0006355	IDA
# CRH	GO:0001963	IDA
# CRH	GO:0006954	IDA
# CRH	GO:0007565	IDA
# CRH	GO:0051461	IDA
# CRH	GO:0051464	IDA
# CRH	GO:2000310	IDA
# CRHBP	GO:0006954	IDA
# CRHBP	GO:0007565	IDA
# CRHBP	GO:0009755	IDA
# CRHBP	GO:0035865	IDA
# CRHBP	GO:0045055	IDA
# CRHBP	GO:0051459	IDA
# CRHBP	GO:0051460	IDA
# CRHBP	GO:0071356	IDA
# CRHBP	GO:0071391	IDA
# CRHBP	GO:0071392	IDA
# ...
# MIR27A	GO:1905598	IDA
# MIR27B	GO:0010628	IDA
# MIR27B	GO:0010629	IDA
# MIR27B	GO:0010872	IDA
# MIR27B	GO:0010989	IDA
# MIR27B	GO:0035195	IDA
# MIR27B	GO:0035278	IDA
# MIR27B	GO:0035924	IDA
# MIR27B	GO:0042632	IDA
# MIR27B	GO:0045599	IDA
# MIR27B	GO:0090050	IDA
# MIR27B	GO:0090370	IDA
# MIR27B	GO:1900131	IDA
# MIR27B	GO:1903589	IDA
# MIR27B	GO:1905596	IDA
# MIR27B	GO:1905601	IDA
# MIR28	GO:0035278	IDA
# MIR29A	GO:0008285	IDA
# MIR29A	GO:0010595	IDA
# MIR29A	GO:0010628	IDA
# MIR29A	GO:0010629	IDA
# MIR29A	GO:0016525	IDA
# MIR29A	GO:0030335	IDA
# MIR29A	GO:0030336	IDA
# MIR29A	GO:0032966	IDA
# MIR29A	GO:0035195	IDA
# MIR29A	GO:0035278	IDA
# MIR29A	GO:0043065	IDA
# MIR29A	GO:0044030	IDA
# MIR29A	GO:0045766	IDA
# MIR29A	GO:0051897	IDA
# MIR29A	GO:0051898	IDA
# MIR29A	GO:0061754	IDA
# MIR29A	GO:1900087	IDA
# MIR29A	GO:1902110	IDA
# MIR29A	GO:1905564	IDA
# MIR29A	GO:2000134	IDA
# MIR296	GO:0010641	IDA
# MIR296	GO:0030949	IDA
# MIR296	GO:0035195	IDA
# MIR299	GO:0035278	IDA
# MIR29B1	GO:0008285	IDA
# MIR29B1	GO:0010628	IDA
# MIR29B1	GO:0010629	IDA
# MIR29B1	GO:0010719	IDA
# MIR29B1	GO:0030335	IDA
# MIR29B1	GO:0030336	IDA
# MIR29B1	GO:0030512	IDA
# MIR29B1	GO:0032966	IDA
# MIR29B1	GO:0035195	IDA
# MIR29B1	GO:0035278	IDA
# MIR29B1	GO:0043065	IDA
# MIR29B1	GO:0043409	IDA
# MIR29B1	GO:0044030	IDA
# MIR29B1	GO:0051898	IDA
# MIR29B1	GO:0061754	IDA
# MIR29B1	GO:0090090	IDA
# MIR29B1	GO:1901223	IDA
# MIR29B1	GO:1902110	IDA
# MIR29B1	GO:1903202	IDA
# MIR29B1	GO:2000134	IDA
# MIR29B2	GO:0008285	IDA
# MIR29B2	GO:0010628	IDA
# MIR29B2	GO:0010629	IDA
# MIR29B2	GO:0010719	IDA
# MIR29B2	GO:0030335	IDA
# MIR29B2	GO:0030336	IDA
# MIR29B2	GO:0030512	IDA
# MIR29B2	GO:0032966	IDA
# MIR29B2	GO:0035195	IDA
# MIR29B2	GO:0035278	IDA
# MIR29B2	GO:0043065	IDA
# MIR29B2	GO:0043409	IDA
# MIR29B2	GO:0044030	IDA
# MIR29B2	GO:0051898	IDA
# MIR29B2	GO:0061754	IDA
# MIR29B2	GO:0090090	IDA
# MIR29B2	GO:1901223	IDA
# MIR29B2	GO:1902110	IDA
# MIR29B2	GO:1903202	IDA
# MIR29B2	GO:2000134	IDA
# MIR29C	GO:0001953	IDA
# MIR29C	GO:0008285	IDA
# MIR29C	GO:0010629	IDA
# MIR29C	GO:0016525	IDA
# MIR29C	GO:0030336	IDA
# MIR29C	GO:0035195	IDA
# MIR29C	GO:0043065	IDA
# MIR29C	GO:0043569	IDA
# MIR29C	GO:0044030	IDA
# MIR29C	GO:0051898	IDA
# MIR29C	GO:0061754	IDA
# MIR29C	GO:0090051	IDA
# MIR29C	GO:1902110	IDA
# MIR29C	GO:1902807	IDA
# MIR29C	GO:1903588	IDA
# MIR29C	GO:1904684	IDA
# MIR29C	GO:1905563	IDA
# MIR29C	GO:2000134	IDA
# MIR301A	GO:0035195	IDA
# MIR301A	GO:1904707	IDA
# MIR302A	GO:0035195	IDA
# MIR302A	GO:0042632	IDA
# MIR302A	GO:0071404	IDA
# MIR302A	GO:0090370	IDA
# MIR30A	GO:0007179	IDA
# MIR30A	GO:0035195	IDA
# MIR30A	GO:0043536	IDA
# MIR30A	GO:0045766	IDA
# MIR30B	GO:0001934	IDA
# MIR30B	GO:0010628	IDA
# MIR30B	GO:0016525	IDA
# MIR30B	GO:0030511	IDA
# MIR30B	GO:0035195	IDA
# MIR30B	GO:1903672	IDA
# MIR30B	GO:1905563	IDA
# MIR30B	GO:2000352	IDA
# MIR30C1	GO:0010868	IDA
# MIR30C1	GO:0035195	IDA
# MIR30C1	GO:0045717	IDA
# MIR30C1	GO:0050709	IDA
# MIR30C1	GO:0071072	IDA
# MIR30C1	GO:0110114	IDA
# MIR30C1	GO:1905884	IDA
# MIR30C2	GO:0008285	IDA
# MIR30C2	GO:0010629	IDA
# MIR30C2	GO:0010868	IDA
# MIR30C2	GO:0030336	IDA
# MIR30C2	GO:0032088	IDA
# MIR30C2	GO:0035195	IDA
# MIR30C2	GO:0045717	IDA
# MIR30C2	GO:0050709	IDA
# MIR30C2	GO:0050728	IDA
# MIR30C2	GO:0071072	IDA
# MIR30C2	GO:0071356	IDA
# MIR30C2	GO:0110114	IDA
# MIR30C2	GO:1901223	IDA
# MIR30C2	GO:1905884	IDA
# MIR30C2	GO:2000134	IDA
# MIR30E	GO:0035195	IDA
# MIR30E	GO:1905563	IDA
# MIR30E	GO:2000352	IDA
# MIR31	GO:0035195	IDA
# MIR31	GO:0035278	IDA
# MIR31	GO:0045766	IDA
# MIR31	GO:0071356	IDA
# MIR31	GO:0090050	IDA
# MIR31	GO:1903672	IDA
# MIR31	GO:1904995	IDA
# MIR32	GO:0035195	IDA
# MIR320A	GO:0035195	IDA
# MIR33A	GO:0010629	IDA
# MIR33A	GO:0035195	IDA
# MIR33A	GO:0070858	IDA
# MIR33A	GO:0090370	IDA
# MIR33A	GO:0120190	IDA
# MIR34A	GO:0006974	IDA
# MIR34A	GO:0010628	IDA
# MIR34A	GO:0010666	IDA
# MIR34A	GO:0016525	IDA
# MIR34A	GO:0033209	IDA
# MIR34A	GO:0035195	IDA
# MIR34A	GO:0050859	IDA
# MIR34A	GO:0051152	IDA
# MIR34A	GO:0061044	IDA
# MIR34A	GO:0071456	IDA
# MIR34A	GO:0071672	IDA
# MIR34A	GO:0090281	IDA
# MIR34A	GO:0110058	IDA
# MIR34A	GO:1901985	IDA
# MIR34A	GO:1903671	IDA
# MIR34A	GO:1904706	IDA
# MIR34A	GO:1904753	IDA
# MIR34A	GO:1905563	IDA
# MIR34A	GO:2000774	IDA
# MIR7-1	GO:0035195	IDA
# MIR7-2	GO:0035195	IDA
# MIR7-3	GO:0035195	IDA
# MIR9-1	GO:0008285	IDA
# MIR9-1	GO:0030336	IDA
# MIR9-1	GO:0031047	IDA
# MIR9-1	GO:0035195	IDA
# MIR9-1	GO:0035278	IDA
# MIR9-1	GO:0046426	IDA
# MIR9-2	GO:0008285	IDA
# MIR9-2	GO:0030336	IDA
# MIR9-2	GO:0031047	IDA
# MIR9-2	GO:0035195	IDA
# MIR9-2	GO:0035278	IDA
# MIR9-2	GO:0046426	IDA
# MIR92A1	GO:0010628	IDA
# MIR92A1	GO:0032755	IDA
# MIR92A1	GO:0035195	IDA
# MIR92A1	GO:0035278	IDA
# MIR92A1	GO:0043507	IDA
# MIR92A1	GO:0043537	IDA
# MIR92A1	GO:0045944	IDA
# MIR92A1	GO:0071404	IDA
# MIR92A1	GO:0071639	IDA
# MIR92A1	GO:0097533	IDA
# MIR92A1	GO:0097699	IDA
# MIR92A1	GO:1903671	IDA
# MIR92A1	GO:1903672	IDA
# MIR92A1	GO:1904905	IDA
# MIR92A1	GO:1904996	IDA
# MIR92A2	GO:0010628	IDA
# MIR92A2	GO:0032755	IDA
# MIR92A2	GO:0035195	IDA
# MIR92A2	GO:0035278	IDA
# MIR92A2	GO:0043507	IDA
# MIR92A2	GO:0043537	IDA
# MIR92A2	GO:0071404	IDA
# MIR92A2	GO:0071639	IDA
# MIR92A2	GO:0097699	IDA
# MIR92A2	GO:1903671	IDA
# MIR92A2	GO:1903672	IDA
# MIR92A2	GO:1904905	IDA
# MIR92A2	GO:1904996	IDA
# MIR93	GO:0035195	IDA
# MIR9-3	GO:0008285	IDA
# MIR9-3	GO:0030336	IDA
# MIR9-3	GO:0031047	IDA
# MIR9-3	GO:0035195	IDA
# MIR9-3	GO:0035278	IDA
# MIR9-3	GO:0046426	IDA
# MIR96	GO:0035195	IDA
# MIR96	GO:0035278	IDA
# MIR96	GO:0071397	IDA
# MIR98	GO:0010716	IDA
# MIR98	GO:0035195	IDA
# MIR98	GO:0035278	IDA
# MIR98	GO:0070104	IDA
# MIR98	GO:1905563	IDA
# MIR99A	GO:0035195	IDA
# MIR99A	GO:0070104	IDA
# MIR99A	GO:1904893	IDA
# MIR99B	GO:0045429	IDA
# MIR99B	GO:0045603	IDA
# MIR99B	GO:0045766	IDA
# MIR17HG	GO:0014739	IDA
# MIR17HG	GO:0030512	IDA
# MIR17HG	GO:0035195	IDA
# DEFB103A	GO:0031640	IDA
# DEFB103A	GO:0050829	IDA
# DEFB103A	GO:0050830	IDA
# PIM3	GO:0006468	IDA
# SLURP2	GO:0095500	IDA
# SLURP2	GO:0099601	IDA
# CARD17	GO:0050713	IDA
# CARD17	GO:0071222	IDA
# LRRC52	GO:0071805	IDA
# LRRC52	GO:1903818	IDA
# MAP1LC3C	GO:0009267	IDA
# MAP1LC3C	GO:0016236	IDA
# MAP1LC3C	GO:0097352	IDA
# NRARP	GO:0007219	IDA
# TARM1	GO:2000515	IDA
# GALNTL6	GO:0018243	IDA
# LMOD2	GO:0030838	IDA
# LMOD2	GO:0045010	IDA
# MIR133B	GO:0008285	IDA
# MIR133B	GO:0010976	IDA
# MIR133B	GO:0030336	IDA
# MIR133B	GO:0035195	IDA
# MIR133B	GO:0035278	IDA
# MIR133B	GO:0043537	IDA
# MIR133B	GO:1905563	IDA
# MIR135B	GO:0035195	IDA
# MIR135B	GO:0035278	IDA
# MIR135B	GO:0043536	IDA
# MIR135B	GO:1904707	IDA
# MIR135B	GO:1904754	IDA
# MIR135B	GO:1905564	IDA
# MIR148B	GO:0035195	IDA
# MIR328	GO:0035195	IDA
# MIR338	GO:0010629	IDA
# MIR338	GO:0030336	IDA
# MIR338	GO:0035195	IDA
# MIR342	GO:0030512	IDA
# MIR342	GO:0035195	IDA
# MIR342	GO:0043536	IDA
# MIR342	GO:0051898	IDA
# MIR342	GO:0062000	IDA
# MIR342	GO:1900747	IDA
# MIR342	GO:1903588	IDA
# MIR345	GO:0035278	IDA
# MIR371A	GO:0035195	IDA
# MIR372	GO:0008284	IDA
# MIR372	GO:0035195	IDA
# MIR372	GO:1900087	IDA
# MIR373	GO:0035195	IDA
# H2AFB2	GO:0006334	IDA
# H2AFB1	GO:0006334	IDA
# MIR361	GO:0035195	IDA
# MIR361	GO:0042534	IDA
# MIR361	GO:0045408	IDA
# MIR361	GO:0050722	IDA
# MIR361	GO:0050727	IDA
# MIR361	GO:0090051	IDA
# MIR361	GO:1903588	IDA
# MIR378A	GO:0032769	IDA
# MIR378A	GO:0035195	IDA
# MIR378A	GO:0035278	IDA
# MIR384	GO:0035195	IDA
# MIR423	GO:0035195	IDA
# MIR424	GO:0001937	IDA
# MIR424	GO:0035195	IDA
# MIR424	GO:0040037	IDA
# MIR424	GO:1900747	IDA
# MIR424	GO:1903588	IDA
# MIR424	GO:1904858	IDA
# MIR424	GO:2000545	IDA
# MIR425	GO:0035195	IDA
# DEFB104B	GO:0002548	IDA
# DEFB104B	GO:0045087	IDA
# DEFB104B	GO:0050829	IDA
# DEFB104B	GO:0050830	IDA
# DEFB104B	GO:0050918	IDA
# DEFB104B	GO:1904628	IDA
# DEFB106B	GO:0045087	IDA
# DEFB106B	GO:0050829	IDA
# DEFB106B	GO:0050830	IDA
# DEFB106B	GO:0061760	IDA
# LURAP1	GO:0001819	IDA
# LURAP1	GO:0043123	IDA
# NBDY	GO:0000956	IDA
# NBDY	GO:0010607	IDA
# BOLA2	GO:0044571	IDA
# BOLA2	GO:0097428	IDA
# MIR429	GO:0035195	IDA
# MIR448	GO:0035195	IDA
# MIR448	GO:1904707	IDA
# MIR448	GO:1904754	IDA
# MIR449A	GO:0008285	IDA
# MIR449A	GO:0010629	IDA
# MIR449A	GO:0014067	IDA
# MIR449A	GO:0030336	IDA
# MIR449A	GO:0035195	IDA
# MIR449A	GO:0051898	IDA
# MIR449A	GO:2001235	IDA
# HIST2H4B	GO:0006334	IDA
# HIST2H4B	GO:0006335	IDA
# HIST2H4B	GO:0006336	IDA
# HIST2H4B	GO:0045653	IDA
# HIST2H4B	GO:0051290	IDA
# DHFRP1	GO:0017148	IDA
# DHFRP1	GO:0046452	IDA
# DHFRP1	GO:0046653	IDA
# DHFRP1	GO:0046654	IDA
# DHFRP1	GO:0055114	IDA
# MIR362	GO:0035195	IDA
# MIR362	GO:1904706	IDA
# MIR362	GO:1904753	IDA
# MIR362	GO:2000134	IDA
# MIR363	GO:0035195	IDA
# MIR20B	GO:0016525	IDA
# MIR20B	GO:0035195	IDA
# MIR20B	GO:0071356	IDA
# MIR18B	GO:0035195	IDA
# MIR329-1	GO:0035195	IDA
# MIR329-1	GO:0038061	IDA
# MIR329-1	GO:1900747	IDA
# MIR329-2	GO:0035195	IDA
# MIR329-2	GO:0038061	IDA
# MIR329-2	GO:1900747	IDA
# MIR451A	GO:0010629	IDA
# MIR451A	GO:0030336	IDA
# MIR451A	GO:0035470	IDA
# MIR451A	GO:0043065	IDA
# MIR451A	GO:0051898	IDA
# MIR451A	GO:1904754	IDA
# MIR451A	GO:2000134	IDA
# MIR409	GO:0035195	IDA
# MIR409	GO:0061754	IDA
# MIR410	GO:0035195	IDA
# MIR410	GO:0090051	IDA
# MIR410	GO:1903588	IDA
# MIR485	GO:0035195	IDA
# MIR485	GO:0060546	IDA
# MIR488	GO:0035195	IDA
# MIR488	GO:0042536	IDA
# MIR488	GO:0045415	IDA
# MIR488	GO:0050724	IDA
# MIR488	GO:0050728	IDA
# MIR491	GO:0030336	IDA
# MIR491	GO:0035195	IDA
# MIR511	GO:0010628	IDA
# MIR511	GO:0035195	IDA
# MIR511	GO:0045666	IDA
# MIR146B	GO:0010764	IDA
# MIR146B	GO:0034121	IDA
# MIR146B	GO:0035195	IDA
# MIR146B	GO:0071222	IDA
# MIR146B	GO:0090272	IDA
# MIR492	GO:0010629	IDA
# MIR492	GO:0016525	IDA
# MIR492	GO:0035195	IDA
# MIR492	GO:0043537	IDA
# MIR492	GO:1905563	IDA
# MIR494	GO:0010629	IDA
# MIR494	GO:0035195	IDA
# MIR494	GO:0090051	IDA
# MIR494	GO:1903588	IDA
# MIR495	GO:0035195	IDA
# MIR495	GO:1900087	IDA
# MIR495	GO:1905564	IDA
# MIR495	GO:2000352	IDA
# MIR193B	GO:0035195	IDA
# MIR497	GO:0035195	IDA
# MIR497	GO:0043124	IDA
# MIR497	GO:0090051	IDA
# MIR497	GO:1903588	IDA
# MIR181D	GO:0045944	IDA
# MIR520E	GO:0035278	IDA
# MIR520E	GO:0045958	IDA
# MIR520E	GO:2000010	IDA
# MIR515-1	GO:0035195	IDA
# MIR519E	GO:0035195	IDA
# MIR515-2	GO:0035195	IDA
# MIR520A	GO:0008284	IDA
# MIR520A	GO:0035195	IDA
# MIR520A	GO:1900087	IDA
# MIR519B	GO:0035195	IDA
# MIR520B	GO:0035195	IDA
# MIR520B	GO:0035278	IDA
# MIR520B	GO:0045958	IDA
# MIR520B	GO:2000010	IDA
# MIR518B	GO:0008285	IDA
# MIR518B	GO:0030336	IDA
# MIR518B	GO:0035195	IDA
# MIR518B	GO:0035278	IDA
# MIR518B	GO:0043065	IDA
# MIR526A1	GO:0035195	IDA
# MIR520C	GO:0035195	IDA
# MIR518C	GO:0035195	IDA
# MIR519D	GO:0008284	IDA
# MIR519D	GO:0035195	IDA
# MIR519D	GO:1900087	IDA
# MIR526A2	GO:0035195	IDA
# MIR518A1	GO:0035195	IDA
# MIR518D	GO:0035195	IDA
# MIR518A2	GO:0035195	IDA
# MIR520H	GO:0035195	IDA
# MIR527	GO:0035195	IDA
# MIR499A	GO:0035195	IDA
# MIR499A	GO:0035278	IDA
# MIR499A	GO:0043536	IDA
# MIR499A	GO:1904707	IDA
# MIR499A	GO:1904754	IDA
# MIR499A	GO:1905564	IDA
# MIR499A	GO:2000727	IDA
# MIR499A	GO:2000818	IDA
# MIR503	GO:0001937	IDA
# MIR503	GO:0010596	IDA
# MIR503	GO:0010812	IDA
# MIR503	GO:0035195	IDA
# MIR503	GO:0035278	IDA
# MIR503	GO:1902807	IDA
# MIR503	GO:1903588	IDA
# MIR503	GO:1904706	IDA
# MIR503	GO:1904753	IDA
# MIR505	GO:0016525	IDA
# MIR505	GO:0035195	IDA
# MIR505	GO:0043537	IDA
# MIR509-1	GO:0010629	IDA
# MIR509-1	GO:0035195	IDA
# MIR509-1	GO:0060045	IDA
# MIR514A1	GO:0035195	IDA
# MIR514A2	GO:0035195	IDA
# MIR514A3	GO:0035195	IDA
# MBOAT4	GO:0018191	IDA
# MIR483	GO:0035195	IDA
# MIR483	GO:0035278	IDA
# ACOT1	GO:0000038	IDA
# ACOT1	GO:0001676	IDA
# ACOT1	GO:0006637	IDA
# AKAIN1	GO:0008104	IDA
# SCX	GO:0006351	IDA
# FAM83G	GO:0030509	IDA
# SETSIP	GO:0045446	IDA
# SETSIP	GO:0045944	IDA
# SKOR2	GO:0030512	IDA
# ANXA8	GO:1900004	IDA
# ANXA8	GO:1900138	IDA
# NCF1	GO:0006612	IDA
# NCF1	GO:0034614	IDA
# NCF1	GO:0071276	IDA
# SRGAP2C	GO:0021816	IDA
# SRGAP2C	GO:0051490	IDA
# SRGAP2C	GO:0061000	IDA
# SRGAP2C	GO:2001224	IDA
# GPR89A	GO:0051452	IDA
# HIST2H3D	GO:0006334	IDA
# BOLA2B	GO:0044571	IDA
# BOLA2B	GO:0097428	IDA
# MIR487B	GO:0035195	IDA
# MIR487B	GO:0090050	IDA
# MIR487B	GO:1903589	IDA
# MIR548C	GO:0010629	IDA
# MIR548C	GO:0035195	IDA
# MIR548C	GO:0060045	IDA
# MIR552	GO:0035195	IDA
# MIR572	GO:0035195	IDA
# MIR582	GO:0035195	IDA
# MIR588	GO:0030336	IDA
# MIR588	GO:0035195	IDA
# MIR590	GO:0008284	IDA
# MIR590	GO:0010719	IDA
# MIR590	GO:0030335	IDA
# MIR590	GO:0035195	IDA
# MIR590	GO:0035278	IDA
# MIR590	GO:0042632	IDA
# MIR590	GO:0045787	IDA
# MIR590	GO:0051005	IDA
# MIR590	GO:0090198	IDA
# MIR590	GO:1903427	IDA
# MIR590	GO:2000352	IDA
# MIR590	GO:2000726	IDA
# MIR590	GO:2000773	IDA
# MIR613	GO:0035195	IDA
# MIR638	GO:0035195	IDA
# MIR638	GO:0048008	IDA
# MIR638	GO:1904706	IDA
# MIR638	GO:1904753	IDA
# MIR638	GO:2000134	IDA
# MIR639	GO:0035195	IDA
# MIR640	GO:0010628	IDA
# MIR640	GO:0016525	IDA
# MIR640	GO:0035195	IDA
# MIR640	GO:0043537	IDA
# MIR654	GO:0035195	IDA
# MIR657	GO:0035195	IDA
# MIR661	GO:0035195	IDA
# MIR663A	GO:0035195	IDA
# RNF208	GO:0051865	IDA
# GXYLT2	GO:0016266	IDA
# KRTAP4-8	GO:0007568	IDA
# KRTAP4-8	GO:0042633	IDA
# DEFA1B	GO:0002227	IDA
# DEFA1B	GO:0010818	IDA
# DEFA1B	GO:0019731	IDA
# DEFA1B	GO:0030520	IDA
# DEFA1B	GO:0031640	IDA
# DEFA1B	GO:0044657	IDA
# DEFA1B	GO:0050830	IDA
# DEFA1B	GO:0051852	IDA
# DEFA1B	GO:0061844	IDA
# CDK11A	GO:0006468	IDA
# CDK11A	GO:0050684	IDA
# CCR2	GO:0019221	IDA
# CCR2	GO:0090026	IDA
# CCR2	GO:2000464	IDA
# ACOD1	GO:0002760	IDA
# ACOD1	GO:0006952	IDA
# ACOD1	GO:0071222	IDA
# ACOD1	GO:0072573	IDA
# CSKMT	GO:0006479	IDA
# CSKMT	GO:0018023	IDA
# CSKMT	GO:0018026	IDA
# CSKMT	GO:0018027	IDA
# CEMP1	GO:0008283	IDA
# CEMP1	GO:0031214	IDA
# CEMP1	GO:0042476	IDA
# RELL1	GO:1900745	IDA
# MIR758	GO:0035195	IDA
# MIR758	GO:0071404	IDA
# MIR758	GO:0090370	IDA
# MIR767	GO:0035195	IDA
# MIR766	GO:0031393	IDA
# MIR766	GO:0035195	IDA
# MIR766	GO:0045409	IDA
# MIR766	GO:0045415	IDA
# MIR766	GO:0050724	IDA
# MIR766	GO:0050728	IDA
# MIR766	GO:0071222	IDA
# MIR766	GO:0071347	IDA
# MIR766	GO:0071356	IDA
# MIR766	GO:1901223	IDA
# MIR766	GO:1904208	IDA
# MIR766	GO:1904465	IDA
# MIR675	GO:0035195	IDA
# MIR298	GO:0035278	IDA
# MIR509-2	GO:0010629	IDA
# MIR509-2	GO:0035195	IDA
# MIR509-2	GO:0060045	IDA
# MIR892B	GO:0008285	IDA
# MIR892B	GO:0030336	IDA
# MIR892B	GO:0035195	IDA
# MIR892B	GO:0043433	IDA
# MIR892B	GO:0061045	IDA
# MIR892B	GO:1904684	IDA
# MIR892B	GO:2000134	IDA
# MIR876	GO:0035195	IDA
# MIR147B	GO:0010628	IDA
# MIR147B	GO:0010629	IDA
# MIR147B	GO:0045746	IDA
# MIR147B	GO:0060253	IDA
# MIR147B	GO:2000736	IDA
# MIR877	GO:0035278	IDA
# MIR665	GO:0031047	IDA
# MIR665	GO:0035195	IDA
# MIR665	GO:0090090	IDA
# MIR665	GO:1904706	IDA
# MIR665	GO:1904753	IDA
# MIR873	GO:0035195	IDA
# MIR873	GO:0060044	IDA
# MIR873	GO:1902807	IDA
# MIR301B	GO:0035195	IDA
# MIR301B	GO:0042953	IDA
# MIR301B	GO:0090370	IDA
# MIR920	GO:0035195	IDA
# MIR920	GO:0042536	IDA
# MIR920	GO:0045415	IDA
# MIR920	GO:0050724	IDA
# MIR920	GO:0050728	IDA
# MIR543	GO:0035195	IDA
# MIR543	GO:2000773	IDA
# MIR208B	GO:0035195	IDA
# MIR509-3	GO:0010629	IDA
# MIR509-3	GO:0035195	IDA
# MIR509-3	GO:0060045	IDA
# MIR939	GO:0001953	IDA
# MIR939	GO:0016525	IDA
# MIR939	GO:0035278	IDA
# MIR939	GO:0043536	IDA
# MIR365A	GO:0035278	IDA
# MIR365B	GO:0035278	IDA
# CD300H	GO:0001816	IDA
# CD300H	GO:0030593	IDA
# KRTAP4-9	GO:0007568	IDA
# KRTAP4-9	GO:0042633	IDA
# CD24	GO:0001775	IDA
# CD24	GO:0007204	IDA
# CD24	GO:0031295	IDA
# CD24	GO:0032597	IDA
# CD24	GO:0042104	IDA
# CD24	GO:0042325	IDA
# CD24	GO:0043406	IDA
# CD24	GO:0043408	IDA
# CD24	GO:0045730	IDA
# TEN1	GO:0032211	IDA
# JMJD7	GO:0018126	IDA
# PLA2G4B	GO:0046475	IDA
# KLLN	GO:0007050	IDA
# MIR1224	GO:0030949	IDA
# MIR1224	GO:0035195	IDA
# MIR1224	GO:0045746	IDA
# MIR1224	GO:1903672	IDA
# MEF2B	GO:0045944	IDA
# WASHC1	GO:0034314	IDA
# WASHC1	GO:0042147	IDA
# DUX4	GO:0006915	IDA
# DUX4	GO:0045944	IDA
# DUX4	GO:0070317	IDA
# MIR1207	GO:0035195	IDA
# MIR1277	GO:0035195	IDA
# MIR1908	GO:0010595	IDA
# MIR1908	GO:0035195	IDA
# MIR1908	GO:1900222	IDA
# MIR1290	GO:0008284	IDA
# MIR1290	GO:0030335	IDA
# MIR548P	GO:0010868	IDA
# MIR548P	GO:0035195	IDA
# MIR548P	GO:0045541	IDA
# MIR548P	GO:0045717	IDA
# MIR711	GO:0035195	IDA
# MIR711	GO:0045736	IDA
# MIR2355	GO:0035195	IDA
# MIR2355	GO:0090051	IDA
# MIR2355	GO:1903588	IDA
# MIR3909	GO:0035195	IDA
# SDIM1	GO:0051402	IDA
# SDIM1	GO:0060548	IDA
# APELA	GO:0060183	IDA
# MICA	GO:0001913	IDA
# MICA	GO:0002418	IDA
# MICA	GO:0006974	IDA
# MICA	GO:0009408	IDA
# MICA	GO:0032815	IDA
# MICA	GO:0042267	IDA
# MICA	GO:0042742	IDA
# MICA	GO:0046629	IDA
# MICA	GO:0051607	IDA
# KLRC4-KLRK1	GO:0034260	IDA
# KLRC4-KLRK1	GO:0042267	IDA
# KLRC4-KLRK1	GO:0045954	IDA
# KLRC4-KLRK1	GO:2000502	IDA
# MIR4686	GO:0035195	IDA
# MIR4632	GO:0035195	IDA
# MIR4632	GO:0036120	IDA
# MIR4632	GO:1904706	IDA
# HIF1A-AS2	GO:0045669	IDA
# HIF1A-AS2	GO:0060965	IDA
# MIR5588	GO:0035195	IDA
# NOTCH2NLC	GO:0021987	IDA
# NOTCH2NLC	GO:0045747	IDA
# LOC100996750	GO:0007568	IDA
# LOC100996750	GO:0042633	IDA
# NOTCH2NLB	GO:0021987	IDA
# NOTCH2NLB	GO:0045747	IDA
# IFNL4	GO:0007260	IDA
# PANO1	GO:0031647	IDA
# PANO1	GO:0043065	IDA
# TBC1D7-LOC100130357	GO:0031398	IDA
# TBC1D7-LOC100130357	GO:0043547	IDA
# PYDC5	GO:0031333	IDA
# PYDC5	GO:0035458	IDA
# PYDC5	GO:0098586	IDA
# CRYZL2P-SEC16B	GO:0007029	IDA
# CRYZL2P-SEC16B	GO:0007031	IDA
# SHLD3	GO:0045830	IDA
# SHLD3	GO:2000042	IDA
# SHLD3	GO:2001034	IDA

# %%
# gene go information for easy access
sql = '''
CREATE VIEW IF NOT EXISTS gene_go_info (symbol, go_id, evidence) AS
SELECT symbol, go_id, evidence
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id == go._id
WHERE evidence IN ("EXP","IDA") ;
'''
cursor.execute(sql)
connection.commit()

# %%
# gene go information 
sql = '''
SELECT *
FROM gene_go_info
LIMIT 10;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# symbol	go_id	evidence
# A2M	GO:0001869	IDA
# AANAT	GO:0006474	IDA
# AANAT	GO:0030187	IDA
# AANAT	GO:0071320	IDA
# AARS	GO:0006419	IDA
# ABCA1	GO:0007040	IDA
# ABCA1	GO:0008203	IDA
# ABCA1	GO:0016197	IDA
# ABCA1	GO:0033344	IDA
# ABCA1	GO:0033700	IDA

# %%
sql = '''
SELECT type, name AS "TABLE NAME"
FROM sqlite_master 
WHERE name = "gene_go_info";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# type	TABLE NAME
# view	gene_go_info

# %% [markdown]
# ```sql
# DROP VIEW [IF EXISTS] view_name;
# ```

# %%
# gene go information for easy access
sql = '''
DROP VIEW IF EXISTS gene_go_info;
'''
cursor.execute(sql)
connection.commit()

# %%
sql = '''
SELECT type, name AS "TABLE NAME"
FROM sqlite_master 
WHERE name = "gene_go_info";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# type	TABLE NAME

# %% [markdown]
# #### JOIN tables
#
# * Multiple tables contain different data that we want to retrieve from a single query
# * In order to assemble data as part of a query, a JOIN between tables is needed
# * This is a very common practice, since it’s rare for all the data you want to be in a single table
#
#
# * INNER JOIN - return only those rows where there is matching content in BOTH tables (is the default when JOIN is used)
# * OUTER JOIN - returns all rows from both tables even if one of the tables is blank
# * SELF JOIN - can be used to join a table to itself (through aliasing), to compare data internal to the table
#
# ```sql
# SELECT ... FROM table1 [INNER] JOIN table2 ON conditional_expression
# ```

# %%
sql = '''
SELECT gi._id, symbol, evidence
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id = go._id
LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# _id	symbol	evidence
# 1	A1BG	TAS
# 1	A1BG	ND
# 1	A1BG	TAS
# 2	A2M	IDA
# 2	A2M	TAS

# %%
sql = '''
SELECT * 
FROM genes
LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# _id	gene_id
# 1	1
# 2	2
# 3	3
# 4	9
# 5	10

# %%
sql = '''
SELECT sql 
FROM sqlite_master
WHERE name = "go_bp";
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# sql
# CREATE TABLE go_bp (
#       _id INTEGER NOT NULL,                         -- REFERENCES  genes
#       go_id CHAR(10) NOT NULL,                      -- GO ID
#       evidence CHAR(3) NOT NULL,                    -- GO evidence code
#       FOREIGN KEY (_id) REFERENCES  genes  (_id)
#     )

# %%
sql = '''
SELECT symbol, gene_id, count(go_id)
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id = go._id
INNER JOIN genes g
ON g._id = gi._id
GROUP BY symbol, gene_id
LIMIT 5;
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# symbol	gene_id	count(go_id)
# A1BG	1	3
# NAT2	10	1
# ADA	100	42
# CDH2	1000	24
# AKT3	10000	13

# %%
sql = '''
SELECT min(go_no)
FROM
(
SELECT symbol, gene_id, count(go_id) go_no
FROM gene_info AS gi
INNER JOIN go_bp AS go
ON gi._id = go._id
INNER JOIN genes g
ON g._id = gi._id
GROUP BY symbol, gene_id
);
'''
cursor.execute(sql)
print(get_header(cursor))
print(get_results(cursor))
# Out:
# min(go_no)
# 1

# %%
# And close()

cursor.close()
connection.close()

# %% [markdown]
# #### To remove the database, delete the .sqlite file.
